# %%
from pennsieve import Pennsieve
from pennsieve.log import get_logger
from pennsieve.api.agent import AgentError, check_port, socket_address, validate_agent_installation, agent_env, agent_cmd
import time
import os
from os.path import (
    isdir,
    isfile,
    join,
    splitext,
    getmtime,
    basename,
    normpath,
    exists,
    expanduser,
    split,
    dirname,
    getsize,
    abspath,
)
import subprocess
import socket
from websocket import create_connection

# %%
sodaJSONObject = {
  "bf-account-selected": {
    "account-name": "SODA-Pennsieve"
  },
  "bf-dataset-selected": {
    "dataset-name": "chex"
  },
  "dataset-structure": {
    "folders": {
      "code": {
        "folders": {
          "test-chunk-ds": {
            "type": "local",
            "path": "/Users/aaronm/test-chunk-ds",
            "folders": {},
            "files": {
              "0.txt": {
                "path": "/Users/aaronm/test-chunk-ds/0.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "10.txt": {
                "path": "/Users/aaronm/test-chunk-ds/10.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "100.txt": {
                "path": "/Users/aaronm/test-chunk-ds/100.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1000.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1000.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1001.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1001.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1002.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1002.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1003.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1003.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1004.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1004.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1005.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1005.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1006.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1006.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1007.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1007.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1008.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1008.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1009.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1009.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "101.txt": {
                "path": "/Users/aaronm/test-chunk-ds/101.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1010.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1010.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1011.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1011.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1012.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1012.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1013.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1013.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1014.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1014.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1015.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1015.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1016.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1016.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1017.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1017.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1018.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1018.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1019.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1019.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "102.txt": {
                "path": "/Users/aaronm/test-chunk-ds/102.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1020.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1020.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1021.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1021.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1022.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1022.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1023.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1023.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1024.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1024.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1025.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1025.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1026.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1026.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1027.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1027.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1028.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1028.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1029.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1029.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "103.txt": {
                "path": "/Users/aaronm/test-chunk-ds/103.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1030.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1030.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1031.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1031.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1032.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1032.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1033.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1033.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1034.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1034.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1035.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1035.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1036.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1036.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1037.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1037.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1038.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1038.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1039.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1039.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "104.txt": {
                "path": "/Users/aaronm/test-chunk-ds/104.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1040.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1040.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1041.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1041.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1042.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1042.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1043.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1043.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1044.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1044.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1045.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1045.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1046.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1046.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1047.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1047.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1048.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1048.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1049.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1049.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "105.txt": {
                "path": "/Users/aaronm/test-chunk-ds/105.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1050.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1050.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1051.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1051.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1052.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1052.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1053.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1053.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1054.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1054.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1055.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1055.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1056.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1056.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1057.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1057.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1058.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1058.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1059.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1059.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "106.txt": {
                "path": "/Users/aaronm/test-chunk-ds/106.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1060.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1060.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1061.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1061.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1062.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1062.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1063.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1063.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1064.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1064.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1065.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1065.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1066.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1066.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1067.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1067.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1068.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1068.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1069.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1069.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "107.txt": {
                "path": "/Users/aaronm/test-chunk-ds/107.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1070.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1070.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1071.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1071.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1072.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1072.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1073.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1073.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1074.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1074.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1075.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1075.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1076.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1076.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1077.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1077.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1078.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1078.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1079.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1079.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "108.txt": {
                "path": "/Users/aaronm/test-chunk-ds/108.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1080.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1080.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1081.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1081.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1082.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1082.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1083.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1083.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1084.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1084.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1085.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1085.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1086.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1086.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1087.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1087.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1088.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1088.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1089.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1089.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "109.txt": {
                "path": "/Users/aaronm/test-chunk-ds/109.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1090.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1090.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1091.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1091.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1092.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1092.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1093.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1093.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1094.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1094.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1095.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1095.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1096.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1096.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1097.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1097.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1098.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1098.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1099.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1099.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "11.txt": {
                "path": "/Users/aaronm/test-chunk-ds/11.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "110.txt": {
                "path": "/Users/aaronm/test-chunk-ds/110.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1100.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1100.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1101.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1101.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1102.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1102.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1103.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1103.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1104.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1104.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1105.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1105.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1106.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1106.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1107.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1107.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1108.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1108.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1109.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1109.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "111.txt": {
                "path": "/Users/aaronm/test-chunk-ds/111.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1110.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1110.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1111.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1111.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1112.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1112.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1113.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1113.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1114.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1114.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1115.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1115.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1116.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1116.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1117.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1117.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1118.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1118.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1119.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1119.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "112.txt": {
                "path": "/Users/aaronm/test-chunk-ds/112.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1120.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1120.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1121.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1121.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1122.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1122.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1123.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1123.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1124.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1124.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1125.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1125.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1126.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1126.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1127.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1127.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1128.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1128.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1129.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1129.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "113.txt": {
                "path": "/Users/aaronm/test-chunk-ds/113.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1130.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1130.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1131.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1131.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1132.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1132.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1133.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1133.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1134.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1134.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1135.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1135.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1136.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1136.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1137.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1137.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1138.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1138.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1139.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1139.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "114.txt": {
                "path": "/Users/aaronm/test-chunk-ds/114.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1140.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1140.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1141.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1141.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1142.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1142.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1143.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1143.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1144.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1144.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1145.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1145.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1146.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1146.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1147.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1147.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1148.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1148.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1149.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1149.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "115.txt": {
                "path": "/Users/aaronm/test-chunk-ds/115.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1150.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1150.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1151.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1151.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1152.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1152.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1153.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1153.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1154.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1154.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1155.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1155.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1156.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1156.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1157.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1157.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1158.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1158.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1159.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1159.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "116.txt": {
                "path": "/Users/aaronm/test-chunk-ds/116.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1160.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1160.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1161.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1161.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1162.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1162.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1163.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1163.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1164.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1164.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1165.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1165.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1166.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1166.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1167.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1167.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1168.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1168.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1169.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1169.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "117.txt": {
                "path": "/Users/aaronm/test-chunk-ds/117.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1170.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1170.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1171.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1171.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1172.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1172.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1173.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1173.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1174.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1174.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1175.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1175.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1176.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1176.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1177.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1177.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1178.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1178.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1179.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1179.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "118.txt": {
                "path": "/Users/aaronm/test-chunk-ds/118.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1180.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1180.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1181.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1181.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1182.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1182.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1183.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1183.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1184.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1184.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1185.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1185.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1186.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1186.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1187.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1187.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1188.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1188.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1189.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1189.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "119.txt": {
                "path": "/Users/aaronm/test-chunk-ds/119.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1190.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1190.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1191.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1191.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1192.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1192.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1193.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1193.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1194.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1194.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1195.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1195.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1196.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1196.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1197.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1197.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1198.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1198.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1199.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1199.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "12.txt": {
                "path": "/Users/aaronm/test-chunk-ds/12.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "120.txt": {
                "path": "/Users/aaronm/test-chunk-ds/120.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1200.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1200.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1201.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1201.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1202.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1202.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1203.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1203.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1204.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1204.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1205.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1205.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1206.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1206.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1207.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1207.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1208.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1208.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1209.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1209.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "121.txt": {
                "path": "/Users/aaronm/test-chunk-ds/121.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1210.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1210.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1211.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1211.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1212.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1212.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1213.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1213.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1214.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1214.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1215.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1215.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1216.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1216.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1217.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1217.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1218.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1218.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1219.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1219.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "122.txt": {
                "path": "/Users/aaronm/test-chunk-ds/122.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1220.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1220.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1221.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1221.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1222.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1222.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1223.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1223.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1224.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1224.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1225.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1225.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1226.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1226.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1227.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1227.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1228.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1228.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1229.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1229.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "123.txt": {
                "path": "/Users/aaronm/test-chunk-ds/123.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1230.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1230.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1231.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1231.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1232.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1232.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1233.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1233.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1234.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1234.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1235.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1235.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1236.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1236.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1237.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1237.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1238.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1238.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1239.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1239.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "124.txt": {
                "path": "/Users/aaronm/test-chunk-ds/124.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1240.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1240.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1241.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1241.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1242.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1242.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1243.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1243.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1244.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1244.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1245.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1245.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1246.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1246.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1247.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1247.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1248.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1248.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1249.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1249.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "125.txt": {
                "path": "/Users/aaronm/test-chunk-ds/125.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1250.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1250.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1251.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1251.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1252.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1252.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1253.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1253.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1254.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1254.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1255.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1255.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1256.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1256.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1257.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1257.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1258.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1258.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1259.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1259.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "126.txt": {
                "path": "/Users/aaronm/test-chunk-ds/126.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1260.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1260.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1261.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1261.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1262.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1262.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1263.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1263.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1264.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1264.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1265.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1265.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1266.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1266.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1267.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1267.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1268.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1268.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1269.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1269.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "127.txt": {
                "path": "/Users/aaronm/test-chunk-ds/127.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1270.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1270.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1271.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1271.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1272.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1272.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1273.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1273.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1274.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1274.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1275.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1275.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1276.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1276.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1277.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1277.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1278.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1278.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1279.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1279.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "128.txt": {
                "path": "/Users/aaronm/test-chunk-ds/128.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1280.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1280.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1281.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1281.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1282.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1282.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1283.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1283.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1284.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1284.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1285.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1285.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1286.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1286.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1287.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1287.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1288.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1288.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1289.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1289.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "129.txt": {
                "path": "/Users/aaronm/test-chunk-ds/129.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1290.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1290.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1291.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1291.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1292.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1292.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1293.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1293.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1294.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1294.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1295.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1295.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1296.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1296.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1297.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1297.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1298.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1298.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1299.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1299.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "13.txt": {
                "path": "/Users/aaronm/test-chunk-ds/13.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "130.txt": {
                "path": "/Users/aaronm/test-chunk-ds/130.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1300.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1300.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1301.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1301.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1302.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1302.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1303.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1303.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1304.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1304.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1305.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1305.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1306.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1306.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1307.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1307.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1308.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1308.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1309.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1309.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "131.txt": {
                "path": "/Users/aaronm/test-chunk-ds/131.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1310.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1310.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1311.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1311.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1312.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1312.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1313.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1313.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1314.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1314.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1315.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1315.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1316.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1316.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1317.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1317.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1318.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1318.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1319.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1319.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "132.txt": {
                "path": "/Users/aaronm/test-chunk-ds/132.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1320.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1320.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1321.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1321.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1322.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1322.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1323.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1323.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1324.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1324.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1325.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1325.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1326.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1326.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1327.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1327.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1328.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1328.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1329.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1329.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "133.txt": {
                "path": "/Users/aaronm/test-chunk-ds/133.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1330.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1330.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1331.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1331.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1332.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1332.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1333.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1333.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1334.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1334.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1335.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1335.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1336.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1336.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1337.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1337.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1338.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1338.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1339.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1339.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "134.txt": {
                "path": "/Users/aaronm/test-chunk-ds/134.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1340.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1340.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1341.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1341.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1342.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1342.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1343.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1343.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1344.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1344.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1345.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1345.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1346.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1346.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1347.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1347.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1348.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1348.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1349.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1349.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "135.txt": {
                "path": "/Users/aaronm/test-chunk-ds/135.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1350.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1350.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1351.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1351.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1352.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1352.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1353.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1353.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1354.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1354.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1355.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1355.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1356.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1356.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1357.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1357.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1358.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1358.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1359.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1359.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "136.txt": {
                "path": "/Users/aaronm/test-chunk-ds/136.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1360.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1360.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1361.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1361.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1362.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1362.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1363.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1363.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1364.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1364.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1365.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1365.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1366.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1366.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1367.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1367.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1368.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1368.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1369.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1369.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "137.txt": {
                "path": "/Users/aaronm/test-chunk-ds/137.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1370.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1370.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1371.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1371.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1372.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1372.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1373.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1373.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1374.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1374.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1375.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1375.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1376.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1376.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1377.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1377.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1378.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1378.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1379.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1379.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "138.txt": {
                "path": "/Users/aaronm/test-chunk-ds/138.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1380.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1380.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1381.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1381.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1382.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1382.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1383.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1383.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1384.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1384.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1385.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1385.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1386.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1386.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1387.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1387.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1388.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1388.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1389.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1389.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "139.txt": {
                "path": "/Users/aaronm/test-chunk-ds/139.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1390.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1390.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1391.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1391.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1392.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1392.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1393.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1393.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1394.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1394.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1395.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1395.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1396.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1396.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1397.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1397.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1398.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1398.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1399.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1399.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "14.txt": {
                "path": "/Users/aaronm/test-chunk-ds/14.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "140.txt": {
                "path": "/Users/aaronm/test-chunk-ds/140.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1400.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1400.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1401.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1401.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1402.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1402.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1403.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1403.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1404.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1404.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1405.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1405.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1406.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1406.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1407.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1407.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1408.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1408.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1409.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1409.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "141.txt": {
                "path": "/Users/aaronm/test-chunk-ds/141.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1410.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1410.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1411.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1411.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1412.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1412.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1413.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1413.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1414.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1414.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1415.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1415.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1416.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1416.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1417.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1417.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1418.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1418.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1419.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1419.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "142.txt": {
                "path": "/Users/aaronm/test-chunk-ds/142.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1420.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1420.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1421.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1421.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1422.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1422.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1423.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1423.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1424.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1424.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1425.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1425.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1426.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1426.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1427.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1427.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1428.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1428.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1429.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1429.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "143.txt": {
                "path": "/Users/aaronm/test-chunk-ds/143.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1430.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1430.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1431.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1431.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1432.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1432.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1433.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1433.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1434.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1434.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1435.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1435.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1436.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1436.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1437.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1437.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1438.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1438.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1439.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1439.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "144.txt": {
                "path": "/Users/aaronm/test-chunk-ds/144.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1440.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1440.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1441.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1441.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1442.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1442.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1443.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1443.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1444.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1444.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1445.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1445.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1446.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1446.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1447.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1447.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1448.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1448.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1449.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1449.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "145.txt": {
                "path": "/Users/aaronm/test-chunk-ds/145.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1450.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1450.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1451.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1451.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1452.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1452.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1453.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1453.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1454.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1454.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1455.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1455.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1456.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1456.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1457.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1457.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1458.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1458.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1459.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1459.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "146.txt": {
                "path": "/Users/aaronm/test-chunk-ds/146.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1460.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1460.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1461.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1461.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1462.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1462.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1463.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1463.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1464.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1464.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1465.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1465.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1466.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1466.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1467.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1467.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1468.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1468.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1469.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1469.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "147.txt": {
                "path": "/Users/aaronm/test-chunk-ds/147.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1470.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1470.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1471.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1471.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1472.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1472.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1473.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1473.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1474.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1474.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1475.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1475.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1476.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1476.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1477.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1477.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1478.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1478.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1479.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1479.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "148.txt": {
                "path": "/Users/aaronm/test-chunk-ds/148.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1480.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1480.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1481.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1481.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1482.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1482.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1483.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1483.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1484.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1484.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1485.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1485.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1486.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1486.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1487.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1487.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1488.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1488.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1489.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1489.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "149.txt": {
                "path": "/Users/aaronm/test-chunk-ds/149.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1490.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1490.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1491.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1491.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1492.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1492.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1493.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1493.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1494.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1494.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1495.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1495.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1496.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1496.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1497.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1497.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1498.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1498.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1499.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1499.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "15.txt": {
                "path": "/Users/aaronm/test-chunk-ds/15.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "150.txt": {
                "path": "/Users/aaronm/test-chunk-ds/150.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1500.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1500.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1501.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1501.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1502.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1502.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1503.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1503.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1504.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1504.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1505.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1505.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1506.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1506.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1507.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1507.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1508.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1508.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1509.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1509.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "151.txt": {
                "path": "/Users/aaronm/test-chunk-ds/151.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1510.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1510.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1511.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1511.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1512.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1512.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1513.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1513.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1514.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1514.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1515.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1515.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1516.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1516.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1517.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1517.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1518.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1518.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1519.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1519.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "152.txt": {
                "path": "/Users/aaronm/test-chunk-ds/152.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1520.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1520.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1521.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1521.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1522.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1522.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1523.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1523.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1524.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1524.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1525.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1525.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1526.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1526.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1527.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1527.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1528.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1528.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1529.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1529.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "153.txt": {
                "path": "/Users/aaronm/test-chunk-ds/153.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1530.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1530.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1531.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1531.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1532.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1532.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1533.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1533.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1534.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1534.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1535.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1535.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1536.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1536.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1537.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1537.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1538.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1538.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1539.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1539.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "154.txt": {
                "path": "/Users/aaronm/test-chunk-ds/154.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1540.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1540.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1541.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1541.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1542.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1542.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1543.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1543.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1544.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1544.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1545.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1545.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1546.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1546.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1547.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1547.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1548.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1548.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1549.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1549.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "155.txt": {
                "path": "/Users/aaronm/test-chunk-ds/155.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1550.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1550.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1551.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1551.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1552.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1552.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1553.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1553.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1554.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1554.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1555.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1555.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1556.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1556.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1557.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1557.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1558.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1558.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1559.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1559.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "156.txt": {
                "path": "/Users/aaronm/test-chunk-ds/156.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1560.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1560.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1561.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1561.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1562.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1562.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1563.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1563.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1564.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1564.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1565.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1565.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1566.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1566.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1567.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1567.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1568.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1568.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1569.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1569.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "157.txt": {
                "path": "/Users/aaronm/test-chunk-ds/157.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1570.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1570.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1571.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1571.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1572.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1572.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1573.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1573.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1574.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1574.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1575.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1575.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1576.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1576.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1577.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1577.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1578.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1578.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1579.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1579.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "158.txt": {
                "path": "/Users/aaronm/test-chunk-ds/158.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1580.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1580.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1581.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1581.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1582.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1582.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1583.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1583.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1584.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1584.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1585.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1585.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1586.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1586.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1587.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1587.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1588.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1588.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1589.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1589.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "159.txt": {
                "path": "/Users/aaronm/test-chunk-ds/159.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1590.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1590.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1591.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1591.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1592.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1592.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1593.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1593.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1594.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1594.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1595.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1595.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1596.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1596.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1597.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1597.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1598.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1598.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1599.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1599.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "16.txt": {
                "path": "/Users/aaronm/test-chunk-ds/16.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "160.txt": {
                "path": "/Users/aaronm/test-chunk-ds/160.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1600.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1600.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1601.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1601.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1602.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1602.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1603.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1603.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1604.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1604.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1605.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1605.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1606.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1606.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1607.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1607.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1608.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1608.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1609.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1609.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "161.txt": {
                "path": "/Users/aaronm/test-chunk-ds/161.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1610.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1610.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1611.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1611.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1612.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1612.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1613.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1613.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1614.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1614.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1615.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1615.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1616.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1616.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1617.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1617.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1618.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1618.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1619.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1619.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "162.txt": {
                "path": "/Users/aaronm/test-chunk-ds/162.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1620.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1620.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1621.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1621.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1622.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1622.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1623.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1623.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1624.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1624.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1625.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1625.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1626.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1626.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1627.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1627.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1628.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1628.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1629.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1629.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "163.txt": {
                "path": "/Users/aaronm/test-chunk-ds/163.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1630.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1630.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1631.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1631.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1632.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1632.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1633.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1633.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1634.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1634.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1635.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1635.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1636.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1636.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1637.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1637.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1638.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1638.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1639.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1639.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "164.txt": {
                "path": "/Users/aaronm/test-chunk-ds/164.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1640.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1640.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1641.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1641.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1642.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1642.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1643.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1643.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1644.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1644.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1645.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1645.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1646.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1646.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1647.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1647.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1648.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1648.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1649.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1649.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "165.txt": {
                "path": "/Users/aaronm/test-chunk-ds/165.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1650.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1650.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1651.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1651.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1652.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1652.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1653.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1653.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1654.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1654.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1655.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1655.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1656.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1656.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1657.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1657.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1658.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1658.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1659.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1659.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "166.txt": {
                "path": "/Users/aaronm/test-chunk-ds/166.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1660.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1660.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1661.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1661.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1662.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1662.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1663.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1663.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1664.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1664.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1665.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1665.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1666.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1666.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1667.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1667.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1668.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1668.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1669.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1669.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "167.txt": {
                "path": "/Users/aaronm/test-chunk-ds/167.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1670.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1670.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1671.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1671.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1672.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1672.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1673.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1673.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1674.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1674.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1675.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1675.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1676.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1676.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1677.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1677.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1678.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1678.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1679.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1679.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "168.txt": {
                "path": "/Users/aaronm/test-chunk-ds/168.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1680.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1680.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1681.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1681.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1682.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1682.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1683.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1683.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1684.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1684.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1685.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1685.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1686.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1686.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1687.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1687.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1688.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1688.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1689.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1689.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "169.txt": {
                "path": "/Users/aaronm/test-chunk-ds/169.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1690.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1690.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1691.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1691.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1692.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1692.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1693.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1693.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1694.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1694.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1695.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1695.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1696.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1696.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1697.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1697.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1698.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1698.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1699.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1699.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "17.txt": {
                "path": "/Users/aaronm/test-chunk-ds/17.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "170.txt": {
                "path": "/Users/aaronm/test-chunk-ds/170.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1700.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1700.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1701.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1701.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1702.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1702.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1703.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1703.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1704.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1704.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1705.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1705.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1706.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1706.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1707.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1707.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1708.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1708.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1709.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1709.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "171.txt": {
                "path": "/Users/aaronm/test-chunk-ds/171.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1710.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1710.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1711.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1711.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1712.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1712.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1713.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1713.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1714.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1714.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1715.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1715.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1716.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1716.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1717.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1717.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1718.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1718.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1719.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1719.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "172.txt": {
                "path": "/Users/aaronm/test-chunk-ds/172.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1720.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1720.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1721.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1721.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1722.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1722.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1723.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1723.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1724.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1724.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1725.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1725.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1726.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1726.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1727.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1727.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1728.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1728.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1729.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1729.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "173.txt": {
                "path": "/Users/aaronm/test-chunk-ds/173.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1730.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1730.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1731.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1731.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1732.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1732.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1733.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1733.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1734.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1734.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1735.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1735.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1736.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1736.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1737.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1737.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1738.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1738.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1739.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1739.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "174.txt": {
                "path": "/Users/aaronm/test-chunk-ds/174.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1740.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1740.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1741.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1741.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1742.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1742.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1743.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1743.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1744.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1744.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1745.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1745.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1746.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1746.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1747.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1747.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1748.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1748.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1749.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1749.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "175.txt": {
                "path": "/Users/aaronm/test-chunk-ds/175.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1750.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1750.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1751.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1751.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1752.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1752.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1753.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1753.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1754.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1754.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1755.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1755.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1756.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1756.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1757.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1757.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1758.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1758.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1759.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1759.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "176.txt": {
                "path": "/Users/aaronm/test-chunk-ds/176.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1760.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1760.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1761.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1761.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1762.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1762.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1763.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1763.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1764.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1764.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1765.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1765.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1766.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1766.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1767.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1767.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1768.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1768.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1769.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1769.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "177.txt": {
                "path": "/Users/aaronm/test-chunk-ds/177.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1770.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1770.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1771.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1771.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1772.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1772.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1773.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1773.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1774.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1774.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1775.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1775.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1776.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1776.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1777.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1777.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1778.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1778.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1779.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1779.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "178.txt": {
                "path": "/Users/aaronm/test-chunk-ds/178.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1780.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1780.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1781.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1781.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1782.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1782.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1783.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1783.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1784.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1784.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1785.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1785.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1786.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1786.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1787.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1787.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1788.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1788.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1789.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1789.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "179.txt": {
                "path": "/Users/aaronm/test-chunk-ds/179.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1790.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1790.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1791.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1791.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1792.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1792.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1793.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1793.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1794.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1794.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1795.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1795.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1796.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1796.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1797.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1797.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1798.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1798.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1799.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1799.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "18.txt": {
                "path": "/Users/aaronm/test-chunk-ds/18.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "180.txt": {
                "path": "/Users/aaronm/test-chunk-ds/180.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1800.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1800.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1801.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1801.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1802.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1802.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1803.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1803.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1804.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1804.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1805.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1805.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1806.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1806.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1807.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1807.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1808.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1808.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1809.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1809.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "181.txt": {
                "path": "/Users/aaronm/test-chunk-ds/181.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1810.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1810.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1811.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1811.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1812.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1812.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1813.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1813.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1814.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1814.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1815.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1815.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1816.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1816.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1817.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1817.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1818.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1818.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1819.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1819.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "182.txt": {
                "path": "/Users/aaronm/test-chunk-ds/182.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1820.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1820.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1821.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1821.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1822.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1822.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1823.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1823.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1824.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1824.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1825.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1825.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1826.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1826.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1827.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1827.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1828.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1828.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1829.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1829.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "183.txt": {
                "path": "/Users/aaronm/test-chunk-ds/183.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1830.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1830.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1831.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1831.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1832.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1832.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1833.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1833.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1834.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1834.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1835.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1835.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1836.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1836.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1837.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1837.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1838.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1838.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1839.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1839.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "184.txt": {
                "path": "/Users/aaronm/test-chunk-ds/184.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1840.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1840.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1841.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1841.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1842.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1842.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1843.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1843.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1844.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1844.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1845.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1845.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1846.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1846.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1847.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1847.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1848.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1848.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1849.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1849.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "185.txt": {
                "path": "/Users/aaronm/test-chunk-ds/185.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1850.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1850.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1851.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1851.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1852.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1852.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1853.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1853.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1854.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1854.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1855.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1855.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1856.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1856.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1857.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1857.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1858.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1858.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1859.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1859.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "186.txt": {
                "path": "/Users/aaronm/test-chunk-ds/186.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1860.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1860.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1861.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1861.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1862.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1862.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1863.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1863.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1864.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1864.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1865.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1865.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1866.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1866.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1867.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1867.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1868.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1868.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1869.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1869.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "187.txt": {
                "path": "/Users/aaronm/test-chunk-ds/187.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1870.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1870.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1871.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1871.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1872.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1872.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1873.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1873.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1874.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1874.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1875.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1875.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1876.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1876.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1877.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1877.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1878.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1878.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1879.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1879.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "188.txt": {
                "path": "/Users/aaronm/test-chunk-ds/188.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1880.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1880.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1881.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1881.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1882.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1882.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1883.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1883.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1884.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1884.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1885.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1885.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1886.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1886.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1887.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1887.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1888.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1888.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1889.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1889.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "189.txt": {
                "path": "/Users/aaronm/test-chunk-ds/189.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1890.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1890.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1891.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1891.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1892.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1892.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1893.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1893.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1894.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1894.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1895.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1895.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1896.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1896.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1897.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1897.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1898.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1898.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1899.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1899.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "19.txt": {
                "path": "/Users/aaronm/test-chunk-ds/19.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "190.txt": {
                "path": "/Users/aaronm/test-chunk-ds/190.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1900.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1900.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1901.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1901.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1902.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1902.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1903.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1903.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1904.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1904.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1905.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1905.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1906.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1906.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1907.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1907.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1908.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1908.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1909.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1909.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "191.txt": {
                "path": "/Users/aaronm/test-chunk-ds/191.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1910.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1910.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1911.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1911.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1912.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1912.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1913.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1913.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1914.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1914.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1915.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1915.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1916.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1916.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1917.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1917.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1918.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1918.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1919.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1919.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "192.txt": {
                "path": "/Users/aaronm/test-chunk-ds/192.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1920.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1920.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1921.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1921.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1922.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1922.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1923.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1923.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1924.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1924.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1925.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1925.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1926.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1926.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1927.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1927.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1928.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1928.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1929.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1929.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "193.txt": {
                "path": "/Users/aaronm/test-chunk-ds/193.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1930.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1930.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1931.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1931.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1932.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1932.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1933.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1933.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1934.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1934.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1935.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1935.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1936.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1936.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1937.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1937.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1938.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1938.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1939.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1939.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "194.txt": {
                "path": "/Users/aaronm/test-chunk-ds/194.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1940.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1940.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1941.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1941.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1942.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1942.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1943.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1943.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1944.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1944.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1945.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1945.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1946.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1946.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1947.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1947.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1948.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1948.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1949.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1949.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "195.txt": {
                "path": "/Users/aaronm/test-chunk-ds/195.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1950.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1950.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1951.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1951.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1952.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1952.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1953.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1953.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1954.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1954.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1955.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1955.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1956.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1956.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1957.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1957.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1958.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1958.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1959.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1959.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "196.txt": {
                "path": "/Users/aaronm/test-chunk-ds/196.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1960.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1960.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1961.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1961.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1962.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1962.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1963.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1963.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1964.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1964.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1965.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1965.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1966.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1966.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1967.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1967.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1968.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1968.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1969.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1969.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "197.txt": {
                "path": "/Users/aaronm/test-chunk-ds/197.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1970.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1970.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1971.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1971.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1972.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1972.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1973.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1973.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1974.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1974.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1975.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1975.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1976.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1976.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1977.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1977.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1978.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1978.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1979.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1979.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "198.txt": {
                "path": "/Users/aaronm/test-chunk-ds/198.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1980.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1980.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1981.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1981.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1982.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1982.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1983.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1983.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1984.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1984.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1985.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1985.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1986.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1986.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1987.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1987.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1988.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1988.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1989.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1989.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "199.txt": {
                "path": "/Users/aaronm/test-chunk-ds/199.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1990.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1990.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1991.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1991.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1992.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1992.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1993.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1993.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1994.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1994.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1995.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1995.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1996.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1996.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1997.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1997.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1998.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1998.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "1999.txt": {
                "path": "/Users/aaronm/test-chunk-ds/1999.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "20.txt": {
                "path": "/Users/aaronm/test-chunk-ds/20.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "200.txt": {
                "path": "/Users/aaronm/test-chunk-ds/200.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2000.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2000.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2001.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2001.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2002.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2002.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2003.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2003.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2004.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2004.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2005.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2005.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2006.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2006.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2007.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2007.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2008.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2008.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2009.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2009.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "201.txt": {
                "path": "/Users/aaronm/test-chunk-ds/201.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2010.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2010.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2011.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2011.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2012.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2012.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2013.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2013.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2014.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2014.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2015.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2015.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2016.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2016.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2017.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2017.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2018.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2018.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2019.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2019.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "202.txt": {
                "path": "/Users/aaronm/test-chunk-ds/202.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2020.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2020.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2021.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2021.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2022.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2022.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2023.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2023.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2024.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2024.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2025.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2025.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2026.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2026.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2027.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2027.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2028.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2028.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2029.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2029.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "203.txt": {
                "path": "/Users/aaronm/test-chunk-ds/203.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2030.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2030.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2031.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2031.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2032.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2032.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2033.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2033.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2034.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2034.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2035.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2035.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2036.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2036.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2037.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2037.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2038.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2038.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2039.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2039.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "204.txt": {
                "path": "/Users/aaronm/test-chunk-ds/204.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2040.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2040.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2041.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2041.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2042.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2042.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2043.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2043.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2044.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2044.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2045.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2045.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2046.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2046.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2047.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2047.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2048.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2048.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2049.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2049.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "205.txt": {
                "path": "/Users/aaronm/test-chunk-ds/205.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2050.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2050.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2051.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2051.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2052.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2052.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2053.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2053.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2054.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2054.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2055.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2055.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2056.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2056.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2057.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2057.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2058.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2058.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2059.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2059.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "206.txt": {
                "path": "/Users/aaronm/test-chunk-ds/206.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2060.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2060.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2061.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2061.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2062.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2062.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2063.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2063.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2064.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2064.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2065.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2065.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2066.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2066.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2067.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2067.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2068.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2068.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2069.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2069.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "207.txt": {
                "path": "/Users/aaronm/test-chunk-ds/207.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2070.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2070.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2071.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2071.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2072.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2072.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2073.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2073.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2074.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2074.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2075.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2075.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2076.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2076.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2077.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2077.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2078.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2078.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2079.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2079.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "208.txt": {
                "path": "/Users/aaronm/test-chunk-ds/208.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2080.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2080.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2081.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2081.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2082.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2082.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2083.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2083.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2084.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2084.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2085.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2085.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2086.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2086.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2087.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2087.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2088.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2088.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2089.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2089.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "209.txt": {
                "path": "/Users/aaronm/test-chunk-ds/209.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2090.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2090.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2091.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2091.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2092.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2092.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2093.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2093.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2094.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2094.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2095.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2095.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2096.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2096.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2097.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2097.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2098.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2098.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2099.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2099.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "21.txt": {
                "path": "/Users/aaronm/test-chunk-ds/21.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "210.txt": {
                "path": "/Users/aaronm/test-chunk-ds/210.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2100.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2100.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2101.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2101.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2102.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2102.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2103.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2103.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2104.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2104.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2105.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2105.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2106.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2106.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2107.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2107.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2108.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2108.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2109.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2109.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "211.txt": {
                "path": "/Users/aaronm/test-chunk-ds/211.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2110.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2110.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2111.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2111.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2112.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2112.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2113.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2113.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2114.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2114.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2115.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2115.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2116.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2116.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2117.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2117.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2118.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2118.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2119.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2119.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "212.txt": {
                "path": "/Users/aaronm/test-chunk-ds/212.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2120.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2120.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2121.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2121.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2122.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2122.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2123.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2123.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2124.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2124.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2125.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2125.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2126.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2126.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2127.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2127.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2128.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2128.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2129.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2129.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "213.txt": {
                "path": "/Users/aaronm/test-chunk-ds/213.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2130.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2130.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2131.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2131.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2132.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2132.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2133.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2133.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2134.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2134.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2135.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2135.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2136.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2136.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2137.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2137.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2138.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2138.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2139.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2139.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "214.txt": {
                "path": "/Users/aaronm/test-chunk-ds/214.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2140.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2140.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2141.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2141.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2142.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2142.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2143.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2143.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2144.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2144.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2145.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2145.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2146.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2146.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2147.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2147.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2148.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2148.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2149.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2149.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "215.txt": {
                "path": "/Users/aaronm/test-chunk-ds/215.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2150.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2150.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2151.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2151.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2152.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2152.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2153.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2153.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2154.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2154.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2155.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2155.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2156.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2156.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2157.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2157.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2158.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2158.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2159.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2159.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "216.txt": {
                "path": "/Users/aaronm/test-chunk-ds/216.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2160.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2160.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2161.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2161.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2162.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2162.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2163.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2163.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2164.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2164.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2165.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2165.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2166.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2166.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2167.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2167.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2168.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2168.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2169.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2169.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "217.txt": {
                "path": "/Users/aaronm/test-chunk-ds/217.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2170.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2170.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2171.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2171.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2172.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2172.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2173.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2173.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2174.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2174.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2175.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2175.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2176.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2176.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2177.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2177.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2178.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2178.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2179.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2179.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "218.txt": {
                "path": "/Users/aaronm/test-chunk-ds/218.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2180.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2180.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2181.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2181.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2182.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2182.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2183.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2183.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2184.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2184.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2185.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2185.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2186.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2186.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2187.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2187.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2188.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2188.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2189.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2189.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "219.txt": {
                "path": "/Users/aaronm/test-chunk-ds/219.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2190.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2190.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2191.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2191.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2192.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2192.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2193.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2193.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2194.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2194.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2195.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2195.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2196.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2196.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2197.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2197.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2198.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2198.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2199.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2199.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "22.txt": {
                "path": "/Users/aaronm/test-chunk-ds/22.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "220.txt": {
                "path": "/Users/aaronm/test-chunk-ds/220.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2200.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2200.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2201.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2201.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2202.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2202.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2203.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2203.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2204.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2204.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2205.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2205.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2206.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2206.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2207.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2207.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2208.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2208.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2209.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2209.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "221.txt": {
                "path": "/Users/aaronm/test-chunk-ds/221.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2210.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2210.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2211.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2211.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2212.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2212.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2213.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2213.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2214.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2214.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2215.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2215.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2216.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2216.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2217.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2217.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2218.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2218.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2219.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2219.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "222.txt": {
                "path": "/Users/aaronm/test-chunk-ds/222.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2220.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2220.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2221.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2221.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2222.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2222.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2223.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2223.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2224.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2224.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2225.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2225.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2226.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2226.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2227.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2227.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2228.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2228.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2229.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2229.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "223.txt": {
                "path": "/Users/aaronm/test-chunk-ds/223.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2230.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2230.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2231.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2231.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2232.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2232.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2233.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2233.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2234.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2234.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2235.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2235.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2236.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2236.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2237.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2237.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2238.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2238.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2239.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2239.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "224.txt": {
                "path": "/Users/aaronm/test-chunk-ds/224.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2240.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2240.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2241.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2241.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2242.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2242.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2243.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2243.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2244.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2244.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2245.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2245.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2246.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2246.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2247.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2247.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2248.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2248.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2249.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2249.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "225.txt": {
                "path": "/Users/aaronm/test-chunk-ds/225.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2250.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2250.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2251.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2251.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2252.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2252.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2253.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2253.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2254.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2254.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2255.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2255.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2256.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2256.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2257.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2257.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2258.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2258.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2259.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2259.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "226.txt": {
                "path": "/Users/aaronm/test-chunk-ds/226.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2260.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2260.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2261.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2261.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2262.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2262.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2263.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2263.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2264.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2264.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2265.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2265.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2266.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2266.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2267.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2267.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2268.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2268.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2269.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2269.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "227.txt": {
                "path": "/Users/aaronm/test-chunk-ds/227.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2270.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2270.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2271.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2271.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2272.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2272.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2273.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2273.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2274.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2274.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2275.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2275.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2276.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2276.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2277.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2277.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2278.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2278.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2279.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2279.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "228.txt": {
                "path": "/Users/aaronm/test-chunk-ds/228.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2280.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2280.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2281.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2281.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2282.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2282.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2283.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2283.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2284.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2284.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2285.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2285.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2286.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2286.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2287.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2287.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2288.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2288.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2289.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2289.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "229.txt": {
                "path": "/Users/aaronm/test-chunk-ds/229.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2290.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2290.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2291.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2291.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2292.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2292.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2293.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2293.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2294.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2294.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2295.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2295.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2296.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2296.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2297.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2297.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2298.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2298.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2299.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2299.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "23.txt": {
                "path": "/Users/aaronm/test-chunk-ds/23.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "230.txt": {
                "path": "/Users/aaronm/test-chunk-ds/230.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2300.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2300.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2301.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2301.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2302.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2302.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2303.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2303.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2304.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2304.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2305.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2305.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2306.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2306.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2307.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2307.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2308.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2308.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2309.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2309.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "231.txt": {
                "path": "/Users/aaronm/test-chunk-ds/231.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2310.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2310.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2311.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2311.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2312.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2312.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2313.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2313.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2314.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2314.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2315.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2315.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2316.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2316.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2317.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2317.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2318.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2318.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2319.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2319.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "232.txt": {
                "path": "/Users/aaronm/test-chunk-ds/232.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2320.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2320.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2321.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2321.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2322.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2322.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2323.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2323.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2324.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2324.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2325.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2325.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2326.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2326.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2327.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2327.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2328.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2328.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2329.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2329.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "233.txt": {
                "path": "/Users/aaronm/test-chunk-ds/233.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2330.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2330.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2331.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2331.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2332.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2332.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2333.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2333.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2334.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2334.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2335.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2335.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2336.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2336.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2337.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2337.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2338.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2338.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2339.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2339.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "234.txt": {
                "path": "/Users/aaronm/test-chunk-ds/234.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2340.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2340.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2341.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2341.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2342.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2342.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2343.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2343.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2344.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2344.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2345.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2345.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2346.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2346.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2347.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2347.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2348.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2348.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2349.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2349.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "235.txt": {
                "path": "/Users/aaronm/test-chunk-ds/235.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2350.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2350.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2351.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2351.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2352.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2352.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2353.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2353.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2354.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2354.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2355.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2355.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2356.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2356.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2357.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2357.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2358.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2358.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2359.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2359.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "236.txt": {
                "path": "/Users/aaronm/test-chunk-ds/236.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2360.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2360.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2361.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2361.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2362.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2362.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2363.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2363.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2364.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2364.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2365.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2365.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2366.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2366.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2367.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2367.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2368.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2368.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2369.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2369.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "237.txt": {
                "path": "/Users/aaronm/test-chunk-ds/237.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2370.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2370.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2371.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2371.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2372.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2372.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2373.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2373.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2374.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2374.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2375.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2375.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2376.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2376.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2377.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2377.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2378.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2378.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2379.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2379.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "238.txt": {
                "path": "/Users/aaronm/test-chunk-ds/238.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2380.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2380.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2381.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2381.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2382.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2382.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2383.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2383.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2384.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2384.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2385.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2385.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2386.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2386.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2387.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2387.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2388.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2388.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2389.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2389.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "239.txt": {
                "path": "/Users/aaronm/test-chunk-ds/239.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2390.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2390.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2391.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2391.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2392.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2392.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2393.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2393.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2394.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2394.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2395.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2395.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2396.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2396.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2397.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2397.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2398.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2398.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2399.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2399.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "24.txt": {
                "path": "/Users/aaronm/test-chunk-ds/24.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "240.txt": {
                "path": "/Users/aaronm/test-chunk-ds/240.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2400.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2400.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2401.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2401.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2402.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2402.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2403.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2403.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2404.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2404.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2405.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2405.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2406.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2406.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2407.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2407.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2408.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2408.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2409.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2409.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "241.txt": {
                "path": "/Users/aaronm/test-chunk-ds/241.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2410.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2410.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2411.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2411.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2412.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2412.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2413.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2413.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2414.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2414.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2415.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2415.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2416.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2416.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2417.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2417.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2418.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2418.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2419.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2419.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "242.txt": {
                "path": "/Users/aaronm/test-chunk-ds/242.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2420.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2420.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2421.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2421.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2422.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2422.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2423.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2423.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2424.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2424.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2425.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2425.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2426.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2426.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2427.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2427.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2428.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2428.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2429.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2429.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "243.txt": {
                "path": "/Users/aaronm/test-chunk-ds/243.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2430.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2430.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2431.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2431.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2432.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2432.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2433.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2433.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2434.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2434.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2435.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2435.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2436.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2436.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2437.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2437.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2438.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2438.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2439.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2439.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "244.txt": {
                "path": "/Users/aaronm/test-chunk-ds/244.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2440.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2440.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2441.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2441.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2442.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2442.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2443.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2443.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2444.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2444.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2445.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2445.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2446.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2446.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2447.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2447.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2448.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2448.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2449.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2449.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "245.txt": {
                "path": "/Users/aaronm/test-chunk-ds/245.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2450.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2450.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2451.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2451.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2452.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2452.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2453.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2453.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2454.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2454.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2455.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2455.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2456.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2456.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2457.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2457.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2458.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2458.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2459.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2459.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "246.txt": {
                "path": "/Users/aaronm/test-chunk-ds/246.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2460.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2460.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2461.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2461.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2462.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2462.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2463.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2463.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2464.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2464.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2465.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2465.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2466.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2466.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2467.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2467.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2468.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2468.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2469.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2469.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "247.txt": {
                "path": "/Users/aaronm/test-chunk-ds/247.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2470.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2470.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2471.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2471.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2472.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2472.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2473.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2473.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2474.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2474.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2475.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2475.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2476.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2476.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2477.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2477.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2478.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2478.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2479.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2479.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "248.txt": {
                "path": "/Users/aaronm/test-chunk-ds/248.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2480.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2480.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2481.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2481.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2482.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2482.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2483.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2483.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2484.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2484.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2485.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2485.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2486.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2486.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2487.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2487.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2488.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2488.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2489.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2489.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "249.txt": {
                "path": "/Users/aaronm/test-chunk-ds/249.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2490.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2490.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2491.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2491.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2492.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2492.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2493.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2493.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2494.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2494.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2495.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2495.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2496.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2496.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2497.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2497.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2498.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2498.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2499.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2499.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "25.txt": {
                "path": "/Users/aaronm/test-chunk-ds/25.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "250.txt": {
                "path": "/Users/aaronm/test-chunk-ds/250.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2500.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2500.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2501.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2501.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2502.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2502.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2503.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2503.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2504.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2504.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2505.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2505.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2506.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2506.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2507.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2507.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2508.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2508.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2509.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2509.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "251.txt": {
                "path": "/Users/aaronm/test-chunk-ds/251.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2510.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2510.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2511.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2511.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2512.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2512.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2513.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2513.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2514.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2514.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2515.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2515.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2516.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2516.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2517.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2517.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2518.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2518.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2519.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2519.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "252.txt": {
                "path": "/Users/aaronm/test-chunk-ds/252.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2520.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2520.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2521.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2521.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2522.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2522.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2523.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2523.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2524.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2524.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2525.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2525.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2526.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2526.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2527.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2527.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2528.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2528.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2529.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2529.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "253.txt": {
                "path": "/Users/aaronm/test-chunk-ds/253.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2530.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2530.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2531.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2531.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2532.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2532.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2533.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2533.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2534.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2534.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2535.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2535.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2536.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2536.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2537.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2537.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2538.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2538.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2539.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2539.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "254.txt": {
                "path": "/Users/aaronm/test-chunk-ds/254.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2540.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2540.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2541.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2541.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2542.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2542.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2543.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2543.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2544.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2544.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2545.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2545.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2546.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2546.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2547.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2547.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2548.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2548.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2549.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2549.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "255.txt": {
                "path": "/Users/aaronm/test-chunk-ds/255.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2550.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2550.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2551.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2551.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2552.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2552.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2553.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2553.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2554.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2554.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2555.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2555.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2556.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2556.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2557.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2557.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2558.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2558.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2559.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2559.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "256.txt": {
                "path": "/Users/aaronm/test-chunk-ds/256.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2560.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2560.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2561.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2561.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2562.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2562.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2563.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2563.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2564.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2564.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2565.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2565.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2566.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2566.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2567.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2567.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2568.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2568.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2569.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2569.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "257.txt": {
                "path": "/Users/aaronm/test-chunk-ds/257.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2570.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2570.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2571.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2571.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2572.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2572.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2573.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2573.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2574.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2574.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2575.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2575.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2576.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2576.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2577.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2577.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2578.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2578.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2579.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2579.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "258.txt": {
                "path": "/Users/aaronm/test-chunk-ds/258.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2580.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2580.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2581.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2581.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2582.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2582.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2583.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2583.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2584.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2584.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2585.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2585.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2586.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2586.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2587.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2587.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2588.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2588.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2589.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2589.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "259.txt": {
                "path": "/Users/aaronm/test-chunk-ds/259.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2590.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2590.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2591.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2591.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2592.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2592.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2593.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2593.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2594.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2594.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2595.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2595.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2596.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2596.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2597.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2597.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2598.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2598.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2599.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2599.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "26.txt": {
                "path": "/Users/aaronm/test-chunk-ds/26.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "260.txt": {
                "path": "/Users/aaronm/test-chunk-ds/260.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2600.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2600.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2601.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2601.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2602.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2602.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2603.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2603.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2604.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2604.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2605.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2605.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2606.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2606.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2607.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2607.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2608.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2608.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2609.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2609.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "261.txt": {
                "path": "/Users/aaronm/test-chunk-ds/261.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2610.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2610.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2611.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2611.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2612.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2612.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2613.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2613.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2614.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2614.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2615.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2615.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2616.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2616.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2617.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2617.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2618.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2618.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2619.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2619.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "262.txt": {
                "path": "/Users/aaronm/test-chunk-ds/262.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2620.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2620.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2621.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2621.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2622.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2622.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2623.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2623.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2624.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2624.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2625.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2625.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2626.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2626.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2627.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2627.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2628.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2628.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2629.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2629.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "263.txt": {
                "path": "/Users/aaronm/test-chunk-ds/263.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2630.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2630.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2631.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2631.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2632.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2632.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2633.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2633.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2634.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2634.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2635.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2635.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2636.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2636.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2637.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2637.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2638.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2638.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2639.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2639.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "264.txt": {
                "path": "/Users/aaronm/test-chunk-ds/264.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2640.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2640.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2641.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2641.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2642.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2642.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2643.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2643.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2644.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2644.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2645.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2645.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2646.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2646.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2647.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2647.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2648.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2648.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2649.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2649.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "265.txt": {
                "path": "/Users/aaronm/test-chunk-ds/265.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2650.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2650.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2651.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2651.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2652.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2652.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2653.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2653.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2654.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2654.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2655.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2655.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2656.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2656.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2657.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2657.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2658.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2658.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2659.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2659.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "266.txt": {
                "path": "/Users/aaronm/test-chunk-ds/266.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2660.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2660.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2661.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2661.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2662.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2662.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2663.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2663.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2664.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2664.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2665.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2665.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2666.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2666.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2667.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2667.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2668.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2668.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2669.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2669.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "267.txt": {
                "path": "/Users/aaronm/test-chunk-ds/267.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2670.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2670.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2671.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2671.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2672.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2672.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2673.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2673.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2674.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2674.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2675.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2675.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2676.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2676.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2677.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2677.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2678.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2678.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2679.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2679.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "268.txt": {
                "path": "/Users/aaronm/test-chunk-ds/268.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2680.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2680.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2681.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2681.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2682.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2682.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2683.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2683.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2684.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2684.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2685.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2685.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2686.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2686.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2687.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2687.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2688.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2688.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2689.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2689.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "269.txt": {
                "path": "/Users/aaronm/test-chunk-ds/269.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2690.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2690.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2691.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2691.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2692.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2692.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2693.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2693.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2694.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2694.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2695.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2695.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2696.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2696.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2697.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2697.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2698.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2698.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2699.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2699.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "27.txt": {
                "path": "/Users/aaronm/test-chunk-ds/27.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "270.txt": {
                "path": "/Users/aaronm/test-chunk-ds/270.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2700.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2700.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2701.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2701.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2702.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2702.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2703.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2703.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2704.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2704.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2705.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2705.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2706.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2706.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2707.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2707.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2708.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2708.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2709.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2709.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "271.txt": {
                "path": "/Users/aaronm/test-chunk-ds/271.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2710.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2710.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2711.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2711.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2712.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2712.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2713.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2713.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2714.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2714.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2715.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2715.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2716.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2716.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2717.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2717.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2718.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2718.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2719.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2719.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "272.txt": {
                "path": "/Users/aaronm/test-chunk-ds/272.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2720.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2720.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2721.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2721.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2722.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2722.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2723.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2723.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2724.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2724.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2725.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2725.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2726.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2726.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2727.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2727.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2728.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2728.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2729.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2729.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "273.txt": {
                "path": "/Users/aaronm/test-chunk-ds/273.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2730.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2730.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2731.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2731.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2732.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2732.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2733.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2733.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2734.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2734.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2735.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2735.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2736.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2736.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2737.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2737.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2738.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2738.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2739.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2739.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "274.txt": {
                "path": "/Users/aaronm/test-chunk-ds/274.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2740.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2740.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2741.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2741.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2742.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2742.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2743.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2743.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2744.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2744.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2745.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2745.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2746.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2746.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2747.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2747.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2748.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2748.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2749.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2749.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "275.txt": {
                "path": "/Users/aaronm/test-chunk-ds/275.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2750.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2750.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2751.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2751.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2752.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2752.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2753.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2753.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2754.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2754.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2755.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2755.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2756.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2756.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2757.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2757.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2758.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2758.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2759.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2759.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "276.txt": {
                "path": "/Users/aaronm/test-chunk-ds/276.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2760.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2760.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2761.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2761.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2762.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2762.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2763.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2763.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2764.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2764.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2765.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2765.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2766.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2766.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2767.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2767.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2768.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2768.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2769.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2769.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "277.txt": {
                "path": "/Users/aaronm/test-chunk-ds/277.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2770.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2770.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2771.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2771.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2772.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2772.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2773.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2773.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2774.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2774.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2775.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2775.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2776.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2776.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2777.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2777.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2778.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2778.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2779.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2779.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "278.txt": {
                "path": "/Users/aaronm/test-chunk-ds/278.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2780.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2780.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2781.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2781.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2782.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2782.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2783.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2783.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2784.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2784.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2785.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2785.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2786.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2786.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2787.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2787.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2788.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2788.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2789.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2789.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "279.txt": {
                "path": "/Users/aaronm/test-chunk-ds/279.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2790.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2790.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2791.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2791.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2792.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2792.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2793.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2793.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2794.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2794.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2795.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2795.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2796.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2796.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2797.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2797.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2798.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2798.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2799.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2799.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "28.txt": {
                "path": "/Users/aaronm/test-chunk-ds/28.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "280.txt": {
                "path": "/Users/aaronm/test-chunk-ds/280.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2800.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2800.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2801.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2801.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2802.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2802.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2803.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2803.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2804.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2804.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2805.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2805.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2806.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2806.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2807.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2807.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2808.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2808.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2809.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2809.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "281.txt": {
                "path": "/Users/aaronm/test-chunk-ds/281.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2810.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2810.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2811.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2811.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2812.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2812.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2813.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2813.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2814.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2814.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2815.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2815.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2816.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2816.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2817.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2817.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2818.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2818.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2819.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2819.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "282.txt": {
                "path": "/Users/aaronm/test-chunk-ds/282.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2820.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2820.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2821.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2821.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2822.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2822.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2823.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2823.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2824.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2824.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2825.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2825.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2826.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2826.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2827.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2827.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2828.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2828.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2829.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2829.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "283.txt": {
                "path": "/Users/aaronm/test-chunk-ds/283.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2830.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2830.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2831.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2831.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2832.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2832.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2833.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2833.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2834.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2834.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2835.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2835.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2836.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2836.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2837.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2837.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2838.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2838.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2839.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2839.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "284.txt": {
                "path": "/Users/aaronm/test-chunk-ds/284.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2840.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2840.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2841.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2841.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2842.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2842.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2843.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2843.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2844.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2844.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2845.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2845.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2846.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2846.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2847.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2847.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2848.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2848.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2849.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2849.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "285.txt": {
                "path": "/Users/aaronm/test-chunk-ds/285.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2850.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2850.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2851.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2851.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2852.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2852.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2853.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2853.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2854.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2854.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2855.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2855.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2856.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2856.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2857.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2857.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2858.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2858.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2859.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2859.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "286.txt": {
                "path": "/Users/aaronm/test-chunk-ds/286.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2860.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2860.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2861.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2861.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2862.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2862.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2863.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2863.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2864.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2864.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2865.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2865.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2866.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2866.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2867.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2867.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2868.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2868.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2869.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2869.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "287.txt": {
                "path": "/Users/aaronm/test-chunk-ds/287.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2870.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2870.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2871.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2871.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2872.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2872.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2873.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2873.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2874.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2874.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2875.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2875.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2876.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2876.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2877.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2877.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2878.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2878.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2879.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2879.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "288.txt": {
                "path": "/Users/aaronm/test-chunk-ds/288.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2880.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2880.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2881.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2881.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2882.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2882.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2883.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2883.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2884.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2884.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2885.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2885.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2886.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2886.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2887.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2887.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2888.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2888.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2889.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2889.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "289.txt": {
                "path": "/Users/aaronm/test-chunk-ds/289.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2890.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2890.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2891.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2891.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2892.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2892.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2893.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2893.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2894.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2894.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2895.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2895.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2896.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2896.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2897.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2897.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2898.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2898.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2899.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2899.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "29.txt": {
                "path": "/Users/aaronm/test-chunk-ds/29.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "290.txt": {
                "path": "/Users/aaronm/test-chunk-ds/290.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2900.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2900.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2901.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2901.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2902.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2902.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2903.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2903.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2904.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2904.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2905.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2905.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2906.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2906.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2907.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2907.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2908.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2908.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2909.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2909.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "291.txt": {
                "path": "/Users/aaronm/test-chunk-ds/291.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2910.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2910.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2911.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2911.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2912.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2912.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2913.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2913.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2914.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2914.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2915.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2915.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2916.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2916.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2917.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2917.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2918.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2918.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2919.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2919.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "292.txt": {
                "path": "/Users/aaronm/test-chunk-ds/292.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2920.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2920.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2921.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2921.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2922.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2922.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2923.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2923.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2924.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2924.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2925.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2925.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2926.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2926.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2927.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2927.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2928.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2928.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2929.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2929.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "293.txt": {
                "path": "/Users/aaronm/test-chunk-ds/293.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2930.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2930.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2931.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2931.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2932.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2932.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2933.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2933.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2934.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2934.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2935.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2935.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2936.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2936.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2937.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2937.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2938.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2938.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2939.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2939.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "294.txt": {
                "path": "/Users/aaronm/test-chunk-ds/294.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2940.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2940.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2941.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2941.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2942.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2942.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2943.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2943.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2944.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2944.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2945.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2945.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2946.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2946.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2947.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2947.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2948.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2948.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2949.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2949.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "295.txt": {
                "path": "/Users/aaronm/test-chunk-ds/295.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2950.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2950.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2951.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2951.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2952.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2952.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2953.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2953.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2954.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2954.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2955.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2955.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2956.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2956.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2957.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2957.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2958.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2958.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2959.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2959.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "296.txt": {
                "path": "/Users/aaronm/test-chunk-ds/296.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2960.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2960.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2961.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2961.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2962.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2962.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2963.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2963.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2964.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2964.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2965.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2965.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2966.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2966.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2967.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2967.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2968.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2968.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2969.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2969.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "297.txt": {
                "path": "/Users/aaronm/test-chunk-ds/297.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2970.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2970.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2971.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2971.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2972.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2972.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2973.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2973.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2974.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2974.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2975.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2975.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2976.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2976.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2977.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2977.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2978.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2978.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2979.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2979.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "298.txt": {
                "path": "/Users/aaronm/test-chunk-ds/298.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2980.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2980.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2981.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2981.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2982.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2982.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2983.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2983.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2984.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2984.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2985.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2985.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2986.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2986.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2987.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2987.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2988.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2988.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2989.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2989.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "299.txt": {
                "path": "/Users/aaronm/test-chunk-ds/299.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2990.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2990.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2991.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2991.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2992.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2992.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2993.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2993.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2994.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2994.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2995.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2995.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2996.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2996.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2997.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2997.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2998.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2998.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "2999.txt": {
                "path": "/Users/aaronm/test-chunk-ds/2999.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "3.txt": {
                "path": "/Users/aaronm/test-chunk-ds/3.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "30.txt": {
                "path": "/Users/aaronm/test-chunk-ds/30.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "300.txt": {
                "path": "/Users/aaronm/test-chunk-ds/300.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "3000.txt": {
                "path": "/Users/aaronm/test-chunk-ds/3000.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "301.txt": {
                "path": "/Users/aaronm/test-chunk-ds/301.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "302.txt": {
                "path": "/Users/aaronm/test-chunk-ds/302.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "303.txt": {
                "path": "/Users/aaronm/test-chunk-ds/303.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "304.txt": {
                "path": "/Users/aaronm/test-chunk-ds/304.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "305.txt": {
                "path": "/Users/aaronm/test-chunk-ds/305.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "306.txt": {
                "path": "/Users/aaronm/test-chunk-ds/306.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "307.txt": {
                "path": "/Users/aaronm/test-chunk-ds/307.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "308.txt": {
                "path": "/Users/aaronm/test-chunk-ds/308.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "309.txt": {
                "path": "/Users/aaronm/test-chunk-ds/309.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "31.txt": {
                "path": "/Users/aaronm/test-chunk-ds/31.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "310.txt": {
                "path": "/Users/aaronm/test-chunk-ds/310.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "311.txt": {
                "path": "/Users/aaronm/test-chunk-ds/311.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "312.txt": {
                "path": "/Users/aaronm/test-chunk-ds/312.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "313.txt": {
                "path": "/Users/aaronm/test-chunk-ds/313.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "314.txt": {
                "path": "/Users/aaronm/test-chunk-ds/314.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "315.txt": {
                "path": "/Users/aaronm/test-chunk-ds/315.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "316.txt": {
                "path": "/Users/aaronm/test-chunk-ds/316.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "317.txt": {
                "path": "/Users/aaronm/test-chunk-ds/317.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "318.txt": {
                "path": "/Users/aaronm/test-chunk-ds/318.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "319.txt": {
                "path": "/Users/aaronm/test-chunk-ds/319.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "32.txt": {
                "path": "/Users/aaronm/test-chunk-ds/32.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "320.txt": {
                "path": "/Users/aaronm/test-chunk-ds/320.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "321.txt": {
                "path": "/Users/aaronm/test-chunk-ds/321.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "322.txt": {
                "path": "/Users/aaronm/test-chunk-ds/322.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "323.txt": {
                "path": "/Users/aaronm/test-chunk-ds/323.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "324.txt": {
                "path": "/Users/aaronm/test-chunk-ds/324.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "325.txt": {
                "path": "/Users/aaronm/test-chunk-ds/325.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "326.txt": {
                "path": "/Users/aaronm/test-chunk-ds/326.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "327.txt": {
                "path": "/Users/aaronm/test-chunk-ds/327.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "328.txt": {
                "path": "/Users/aaronm/test-chunk-ds/328.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "329.txt": {
                "path": "/Users/aaronm/test-chunk-ds/329.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "33.txt": {
                "path": "/Users/aaronm/test-chunk-ds/33.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "330.txt": {
                "path": "/Users/aaronm/test-chunk-ds/330.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "331.txt": {
                "path": "/Users/aaronm/test-chunk-ds/331.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "332.txt": {
                "path": "/Users/aaronm/test-chunk-ds/332.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "333.txt": {
                "path": "/Users/aaronm/test-chunk-ds/333.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "334.txt": {
                "path": "/Users/aaronm/test-chunk-ds/334.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "335.txt": {
                "path": "/Users/aaronm/test-chunk-ds/335.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "336.txt": {
                "path": "/Users/aaronm/test-chunk-ds/336.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "337.txt": {
                "path": "/Users/aaronm/test-chunk-ds/337.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "338.txt": {
                "path": "/Users/aaronm/test-chunk-ds/338.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "339.txt": {
                "path": "/Users/aaronm/test-chunk-ds/339.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "34.txt": {
                "path": "/Users/aaronm/test-chunk-ds/34.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "340.txt": {
                "path": "/Users/aaronm/test-chunk-ds/340.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "341.txt": {
                "path": "/Users/aaronm/test-chunk-ds/341.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "342.txt": {
                "path": "/Users/aaronm/test-chunk-ds/342.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "343.txt": {
                "path": "/Users/aaronm/test-chunk-ds/343.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "344.txt": {
                "path": "/Users/aaronm/test-chunk-ds/344.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "345.txt": {
                "path": "/Users/aaronm/test-chunk-ds/345.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "346.txt": {
                "path": "/Users/aaronm/test-chunk-ds/346.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "347.txt": {
                "path": "/Users/aaronm/test-chunk-ds/347.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "348.txt": {
                "path": "/Users/aaronm/test-chunk-ds/348.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "349.txt": {
                "path": "/Users/aaronm/test-chunk-ds/349.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "35.txt": {
                "path": "/Users/aaronm/test-chunk-ds/35.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "350.txt": {
                "path": "/Users/aaronm/test-chunk-ds/350.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "351.txt": {
                "path": "/Users/aaronm/test-chunk-ds/351.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "352.txt": {
                "path": "/Users/aaronm/test-chunk-ds/352.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "353.txt": {
                "path": "/Users/aaronm/test-chunk-ds/353.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "354.txt": {
                "path": "/Users/aaronm/test-chunk-ds/354.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "355.txt": {
                "path": "/Users/aaronm/test-chunk-ds/355.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "356.txt": {
                "path": "/Users/aaronm/test-chunk-ds/356.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "357.txt": {
                "path": "/Users/aaronm/test-chunk-ds/357.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "358.txt": {
                "path": "/Users/aaronm/test-chunk-ds/358.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "359.txt": {
                "path": "/Users/aaronm/test-chunk-ds/359.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "36.txt": {
                "path": "/Users/aaronm/test-chunk-ds/36.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "360.txt": {
                "path": "/Users/aaronm/test-chunk-ds/360.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "361.txt": {
                "path": "/Users/aaronm/test-chunk-ds/361.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "362.txt": {
                "path": "/Users/aaronm/test-chunk-ds/362.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "363.txt": {
                "path": "/Users/aaronm/test-chunk-ds/363.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "364.txt": {
                "path": "/Users/aaronm/test-chunk-ds/364.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "365.txt": {
                "path": "/Users/aaronm/test-chunk-ds/365.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "366.txt": {
                "path": "/Users/aaronm/test-chunk-ds/366.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "367.txt": {
                "path": "/Users/aaronm/test-chunk-ds/367.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "368.txt": {
                "path": "/Users/aaronm/test-chunk-ds/368.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "369.txt": {
                "path": "/Users/aaronm/test-chunk-ds/369.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "37.txt": {
                "path": "/Users/aaronm/test-chunk-ds/37.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "370.txt": {
                "path": "/Users/aaronm/test-chunk-ds/370.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "371.txt": {
                "path": "/Users/aaronm/test-chunk-ds/371.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "372.txt": {
                "path": "/Users/aaronm/test-chunk-ds/372.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "373.txt": {
                "path": "/Users/aaronm/test-chunk-ds/373.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "374.txt": {
                "path": "/Users/aaronm/test-chunk-ds/374.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "375.txt": {
                "path": "/Users/aaronm/test-chunk-ds/375.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "376.txt": {
                "path": "/Users/aaronm/test-chunk-ds/376.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "377.txt": {
                "path": "/Users/aaronm/test-chunk-ds/377.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "378.txt": {
                "path": "/Users/aaronm/test-chunk-ds/378.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "379.txt": {
                "path": "/Users/aaronm/test-chunk-ds/379.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "38.txt": {
                "path": "/Users/aaronm/test-chunk-ds/38.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "380.txt": {
                "path": "/Users/aaronm/test-chunk-ds/380.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "381.txt": {
                "path": "/Users/aaronm/test-chunk-ds/381.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "382.txt": {
                "path": "/Users/aaronm/test-chunk-ds/382.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "383.txt": {
                "path": "/Users/aaronm/test-chunk-ds/383.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "384.txt": {
                "path": "/Users/aaronm/test-chunk-ds/384.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "385.txt": {
                "path": "/Users/aaronm/test-chunk-ds/385.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "386.txt": {
                "path": "/Users/aaronm/test-chunk-ds/386.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "387.txt": {
                "path": "/Users/aaronm/test-chunk-ds/387.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "388.txt": {
                "path": "/Users/aaronm/test-chunk-ds/388.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "389.txt": {
                "path": "/Users/aaronm/test-chunk-ds/389.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "39.txt": {
                "path": "/Users/aaronm/test-chunk-ds/39.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "390.txt": {
                "path": "/Users/aaronm/test-chunk-ds/390.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "391.txt": {
                "path": "/Users/aaronm/test-chunk-ds/391.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "392.txt": {
                "path": "/Users/aaronm/test-chunk-ds/392.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "393.txt": {
                "path": "/Users/aaronm/test-chunk-ds/393.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "394.txt": {
                "path": "/Users/aaronm/test-chunk-ds/394.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "395.txt": {
                "path": "/Users/aaronm/test-chunk-ds/395.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "396.txt": {
                "path": "/Users/aaronm/test-chunk-ds/396.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "397.txt": {
                "path": "/Users/aaronm/test-chunk-ds/397.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "398.txt": {
                "path": "/Users/aaronm/test-chunk-ds/398.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "399.txt": {
                "path": "/Users/aaronm/test-chunk-ds/399.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "4.txt": {
                "path": "/Users/aaronm/test-chunk-ds/4.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "40.txt": {
                "path": "/Users/aaronm/test-chunk-ds/40.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "400.txt": {
                "path": "/Users/aaronm/test-chunk-ds/400.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "401.txt": {
                "path": "/Users/aaronm/test-chunk-ds/401.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "402.txt": {
                "path": "/Users/aaronm/test-chunk-ds/402.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "403.txt": {
                "path": "/Users/aaronm/test-chunk-ds/403.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "404.txt": {
                "path": "/Users/aaronm/test-chunk-ds/404.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "405.txt": {
                "path": "/Users/aaronm/test-chunk-ds/405.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "406.txt": {
                "path": "/Users/aaronm/test-chunk-ds/406.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "407.txt": {
                "path": "/Users/aaronm/test-chunk-ds/407.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "408.txt": {
                "path": "/Users/aaronm/test-chunk-ds/408.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "409.txt": {
                "path": "/Users/aaronm/test-chunk-ds/409.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "41.txt": {
                "path": "/Users/aaronm/test-chunk-ds/41.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "410.txt": {
                "path": "/Users/aaronm/test-chunk-ds/410.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "411.txt": {
                "path": "/Users/aaronm/test-chunk-ds/411.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "412.txt": {
                "path": "/Users/aaronm/test-chunk-ds/412.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "413.txt": {
                "path": "/Users/aaronm/test-chunk-ds/413.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "414.txt": {
                "path": "/Users/aaronm/test-chunk-ds/414.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "415.txt": {
                "path": "/Users/aaronm/test-chunk-ds/415.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "416.txt": {
                "path": "/Users/aaronm/test-chunk-ds/416.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "417.txt": {
                "path": "/Users/aaronm/test-chunk-ds/417.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "418.txt": {
                "path": "/Users/aaronm/test-chunk-ds/418.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "419.txt": {
                "path": "/Users/aaronm/test-chunk-ds/419.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "42.txt": {
                "path": "/Users/aaronm/test-chunk-ds/42.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "420.txt": {
                "path": "/Users/aaronm/test-chunk-ds/420.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "421.txt": {
                "path": "/Users/aaronm/test-chunk-ds/421.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "422.txt": {
                "path": "/Users/aaronm/test-chunk-ds/422.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "423.txt": {
                "path": "/Users/aaronm/test-chunk-ds/423.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "424.txt": {
                "path": "/Users/aaronm/test-chunk-ds/424.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "425.txt": {
                "path": "/Users/aaronm/test-chunk-ds/425.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "426.txt": {
                "path": "/Users/aaronm/test-chunk-ds/426.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "427.txt": {
                "path": "/Users/aaronm/test-chunk-ds/427.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "428.txt": {
                "path": "/Users/aaronm/test-chunk-ds/428.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "429.txt": {
                "path": "/Users/aaronm/test-chunk-ds/429.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "43.txt": {
                "path": "/Users/aaronm/test-chunk-ds/43.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "430.txt": {
                "path": "/Users/aaronm/test-chunk-ds/430.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "431.txt": {
                "path": "/Users/aaronm/test-chunk-ds/431.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "432.txt": {
                "path": "/Users/aaronm/test-chunk-ds/432.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "433.txt": {
                "path": "/Users/aaronm/test-chunk-ds/433.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "434.txt": {
                "path": "/Users/aaronm/test-chunk-ds/434.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "435.txt": {
                "path": "/Users/aaronm/test-chunk-ds/435.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "436.txt": {
                "path": "/Users/aaronm/test-chunk-ds/436.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "437.txt": {
                "path": "/Users/aaronm/test-chunk-ds/437.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "438.txt": {
                "path": "/Users/aaronm/test-chunk-ds/438.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "439.txt": {
                "path": "/Users/aaronm/test-chunk-ds/439.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "44.txt": {
                "path": "/Users/aaronm/test-chunk-ds/44.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "440.txt": {
                "path": "/Users/aaronm/test-chunk-ds/440.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "441.txt": {
                "path": "/Users/aaronm/test-chunk-ds/441.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "442.txt": {
                "path": "/Users/aaronm/test-chunk-ds/442.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "443.txt": {
                "path": "/Users/aaronm/test-chunk-ds/443.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "444.txt": {
                "path": "/Users/aaronm/test-chunk-ds/444.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "445.txt": {
                "path": "/Users/aaronm/test-chunk-ds/445.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "446.txt": {
                "path": "/Users/aaronm/test-chunk-ds/446.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "447.txt": {
                "path": "/Users/aaronm/test-chunk-ds/447.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "448.txt": {
                "path": "/Users/aaronm/test-chunk-ds/448.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "449.txt": {
                "path": "/Users/aaronm/test-chunk-ds/449.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "45.txt": {
                "path": "/Users/aaronm/test-chunk-ds/45.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "450.txt": {
                "path": "/Users/aaronm/test-chunk-ds/450.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "451.txt": {
                "path": "/Users/aaronm/test-chunk-ds/451.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "452.txt": {
                "path": "/Users/aaronm/test-chunk-ds/452.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "453.txt": {
                "path": "/Users/aaronm/test-chunk-ds/453.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "454.txt": {
                "path": "/Users/aaronm/test-chunk-ds/454.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "455.txt": {
                "path": "/Users/aaronm/test-chunk-ds/455.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "456.txt": {
                "path": "/Users/aaronm/test-chunk-ds/456.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "457.txt": {
                "path": "/Users/aaronm/test-chunk-ds/457.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "458.txt": {
                "path": "/Users/aaronm/test-chunk-ds/458.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "459.txt": {
                "path": "/Users/aaronm/test-chunk-ds/459.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "46.txt": {
                "path": "/Users/aaronm/test-chunk-ds/46.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "460.txt": {
                "path": "/Users/aaronm/test-chunk-ds/460.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "461.txt": {
                "path": "/Users/aaronm/test-chunk-ds/461.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "462.txt": {
                "path": "/Users/aaronm/test-chunk-ds/462.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "463.txt": {
                "path": "/Users/aaronm/test-chunk-ds/463.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "464.txt": {
                "path": "/Users/aaronm/test-chunk-ds/464.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "465.txt": {
                "path": "/Users/aaronm/test-chunk-ds/465.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "466.txt": {
                "path": "/Users/aaronm/test-chunk-ds/466.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "467.txt": {
                "path": "/Users/aaronm/test-chunk-ds/467.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "468.txt": {
                "path": "/Users/aaronm/test-chunk-ds/468.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "469.txt": {
                "path": "/Users/aaronm/test-chunk-ds/469.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "47.txt": {
                "path": "/Users/aaronm/test-chunk-ds/47.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "470.txt": {
                "path": "/Users/aaronm/test-chunk-ds/470.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "471.txt": {
                "path": "/Users/aaronm/test-chunk-ds/471.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "472.txt": {
                "path": "/Users/aaronm/test-chunk-ds/472.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "473.txt": {
                "path": "/Users/aaronm/test-chunk-ds/473.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "474.txt": {
                "path": "/Users/aaronm/test-chunk-ds/474.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "475.txt": {
                "path": "/Users/aaronm/test-chunk-ds/475.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "476.txt": {
                "path": "/Users/aaronm/test-chunk-ds/476.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "477.txt": {
                "path": "/Users/aaronm/test-chunk-ds/477.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "478.txt": {
                "path": "/Users/aaronm/test-chunk-ds/478.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "479.txt": {
                "path": "/Users/aaronm/test-chunk-ds/479.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "48.txt": {
                "path": "/Users/aaronm/test-chunk-ds/48.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "480.txt": {
                "path": "/Users/aaronm/test-chunk-ds/480.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "481.txt": {
                "path": "/Users/aaronm/test-chunk-ds/481.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "482.txt": {
                "path": "/Users/aaronm/test-chunk-ds/482.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "483.txt": {
                "path": "/Users/aaronm/test-chunk-ds/483.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "484.txt": {
                "path": "/Users/aaronm/test-chunk-ds/484.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "485.txt": {
                "path": "/Users/aaronm/test-chunk-ds/485.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "486.txt": {
                "path": "/Users/aaronm/test-chunk-ds/486.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "487.txt": {
                "path": "/Users/aaronm/test-chunk-ds/487.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "488.txt": {
                "path": "/Users/aaronm/test-chunk-ds/488.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "489.txt": {
                "path": "/Users/aaronm/test-chunk-ds/489.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "49.txt": {
                "path": "/Users/aaronm/test-chunk-ds/49.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "490.txt": {
                "path": "/Users/aaronm/test-chunk-ds/490.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "491.txt": {
                "path": "/Users/aaronm/test-chunk-ds/491.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "492.txt": {
                "path": "/Users/aaronm/test-chunk-ds/492.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "493.txt": {
                "path": "/Users/aaronm/test-chunk-ds/493.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "494.txt": {
                "path": "/Users/aaronm/test-chunk-ds/494.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "495.txt": {
                "path": "/Users/aaronm/test-chunk-ds/495.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "496.txt": {
                "path": "/Users/aaronm/test-chunk-ds/496.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "497.txt": {
                "path": "/Users/aaronm/test-chunk-ds/497.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "498.txt": {
                "path": "/Users/aaronm/test-chunk-ds/498.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "499.txt": {
                "path": "/Users/aaronm/test-chunk-ds/499.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "5.txt": {
                "path": "/Users/aaronm/test-chunk-ds/5.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "50.txt": {
                "path": "/Users/aaronm/test-chunk-ds/50.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "500.txt": {
                "path": "/Users/aaronm/test-chunk-ds/500.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "501.txt": {
                "path": "/Users/aaronm/test-chunk-ds/501.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "502.txt": {
                "path": "/Users/aaronm/test-chunk-ds/502.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "503.txt": {
                "path": "/Users/aaronm/test-chunk-ds/503.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "504.txt": {
                "path": "/Users/aaronm/test-chunk-ds/504.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "505.txt": {
                "path": "/Users/aaronm/test-chunk-ds/505.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "506.txt": {
                "path": "/Users/aaronm/test-chunk-ds/506.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "507.txt": {
                "path": "/Users/aaronm/test-chunk-ds/507.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "508.txt": {
                "path": "/Users/aaronm/test-chunk-ds/508.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "509.txt": {
                "path": "/Users/aaronm/test-chunk-ds/509.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "51.txt": {
                "path": "/Users/aaronm/test-chunk-ds/51.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "510.txt": {
                "path": "/Users/aaronm/test-chunk-ds/510.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "511.txt": {
                "path": "/Users/aaronm/test-chunk-ds/511.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "512.txt": {
                "path": "/Users/aaronm/test-chunk-ds/512.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "513.txt": {
                "path": "/Users/aaronm/test-chunk-ds/513.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "514.txt": {
                "path": "/Users/aaronm/test-chunk-ds/514.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "515.txt": {
                "path": "/Users/aaronm/test-chunk-ds/515.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "516.txt": {
                "path": "/Users/aaronm/test-chunk-ds/516.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "517.txt": {
                "path": "/Users/aaronm/test-chunk-ds/517.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "518.txt": {
                "path": "/Users/aaronm/test-chunk-ds/518.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "519.txt": {
                "path": "/Users/aaronm/test-chunk-ds/519.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "52.txt": {
                "path": "/Users/aaronm/test-chunk-ds/52.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "520.txt": {
                "path": "/Users/aaronm/test-chunk-ds/520.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "521.txt": {
                "path": "/Users/aaronm/test-chunk-ds/521.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "522.txt": {
                "path": "/Users/aaronm/test-chunk-ds/522.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "523.txt": {
                "path": "/Users/aaronm/test-chunk-ds/523.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "524.txt": {
                "path": "/Users/aaronm/test-chunk-ds/524.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "525.txt": {
                "path": "/Users/aaronm/test-chunk-ds/525.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "526.txt": {
                "path": "/Users/aaronm/test-chunk-ds/526.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "527.txt": {
                "path": "/Users/aaronm/test-chunk-ds/527.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "528.txt": {
                "path": "/Users/aaronm/test-chunk-ds/528.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "529.txt": {
                "path": "/Users/aaronm/test-chunk-ds/529.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "53.txt": {
                "path": "/Users/aaronm/test-chunk-ds/53.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "530.txt": {
                "path": "/Users/aaronm/test-chunk-ds/530.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "531.txt": {
                "path": "/Users/aaronm/test-chunk-ds/531.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "532.txt": {
                "path": "/Users/aaronm/test-chunk-ds/532.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "533.txt": {
                "path": "/Users/aaronm/test-chunk-ds/533.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "534.txt": {
                "path": "/Users/aaronm/test-chunk-ds/534.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "535.txt": {
                "path": "/Users/aaronm/test-chunk-ds/535.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "536.txt": {
                "path": "/Users/aaronm/test-chunk-ds/536.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "537.txt": {
                "path": "/Users/aaronm/test-chunk-ds/537.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "538.txt": {
                "path": "/Users/aaronm/test-chunk-ds/538.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "539.txt": {
                "path": "/Users/aaronm/test-chunk-ds/539.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "54.txt": {
                "path": "/Users/aaronm/test-chunk-ds/54.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "540.txt": {
                "path": "/Users/aaronm/test-chunk-ds/540.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "541.txt": {
                "path": "/Users/aaronm/test-chunk-ds/541.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "542.txt": {
                "path": "/Users/aaronm/test-chunk-ds/542.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "543.txt": {
                "path": "/Users/aaronm/test-chunk-ds/543.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "544.txt": {
                "path": "/Users/aaronm/test-chunk-ds/544.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "545.txt": {
                "path": "/Users/aaronm/test-chunk-ds/545.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "546.txt": {
                "path": "/Users/aaronm/test-chunk-ds/546.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "547.txt": {
                "path": "/Users/aaronm/test-chunk-ds/547.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "548.txt": {
                "path": "/Users/aaronm/test-chunk-ds/548.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "549.txt": {
                "path": "/Users/aaronm/test-chunk-ds/549.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "55.txt": {
                "path": "/Users/aaronm/test-chunk-ds/55.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "550.txt": {
                "path": "/Users/aaronm/test-chunk-ds/550.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "551.txt": {
                "path": "/Users/aaronm/test-chunk-ds/551.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "552.txt": {
                "path": "/Users/aaronm/test-chunk-ds/552.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "553.txt": {
                "path": "/Users/aaronm/test-chunk-ds/553.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "554.txt": {
                "path": "/Users/aaronm/test-chunk-ds/554.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "555.txt": {
                "path": "/Users/aaronm/test-chunk-ds/555.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "556.txt": {
                "path": "/Users/aaronm/test-chunk-ds/556.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "557.txt": {
                "path": "/Users/aaronm/test-chunk-ds/557.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "558.txt": {
                "path": "/Users/aaronm/test-chunk-ds/558.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "559.txt": {
                "path": "/Users/aaronm/test-chunk-ds/559.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "56.txt": {
                "path": "/Users/aaronm/test-chunk-ds/56.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "560.txt": {
                "path": "/Users/aaronm/test-chunk-ds/560.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "561.txt": {
                "path": "/Users/aaronm/test-chunk-ds/561.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "562.txt": {
                "path": "/Users/aaronm/test-chunk-ds/562.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "563.txt": {
                "path": "/Users/aaronm/test-chunk-ds/563.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "564.txt": {
                "path": "/Users/aaronm/test-chunk-ds/564.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "565.txt": {
                "path": "/Users/aaronm/test-chunk-ds/565.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "566.txt": {
                "path": "/Users/aaronm/test-chunk-ds/566.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "567.txt": {
                "path": "/Users/aaronm/test-chunk-ds/567.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "568.txt": {
                "path": "/Users/aaronm/test-chunk-ds/568.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "569.txt": {
                "path": "/Users/aaronm/test-chunk-ds/569.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "57.txt": {
                "path": "/Users/aaronm/test-chunk-ds/57.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "570.txt": {
                "path": "/Users/aaronm/test-chunk-ds/570.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "571.txt": {
                "path": "/Users/aaronm/test-chunk-ds/571.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "572.txt": {
                "path": "/Users/aaronm/test-chunk-ds/572.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "573.txt": {
                "path": "/Users/aaronm/test-chunk-ds/573.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "574.txt": {
                "path": "/Users/aaronm/test-chunk-ds/574.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "575.txt": {
                "path": "/Users/aaronm/test-chunk-ds/575.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "576.txt": {
                "path": "/Users/aaronm/test-chunk-ds/576.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "577.txt": {
                "path": "/Users/aaronm/test-chunk-ds/577.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "578.txt": {
                "path": "/Users/aaronm/test-chunk-ds/578.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "579.txt": {
                "path": "/Users/aaronm/test-chunk-ds/579.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "58.txt": {
                "path": "/Users/aaronm/test-chunk-ds/58.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "580.txt": {
                "path": "/Users/aaronm/test-chunk-ds/580.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "581.txt": {
                "path": "/Users/aaronm/test-chunk-ds/581.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "582.txt": {
                "path": "/Users/aaronm/test-chunk-ds/582.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "583.txt": {
                "path": "/Users/aaronm/test-chunk-ds/583.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "584.txt": {
                "path": "/Users/aaronm/test-chunk-ds/584.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "585.txt": {
                "path": "/Users/aaronm/test-chunk-ds/585.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "586.txt": {
                "path": "/Users/aaronm/test-chunk-ds/586.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "587.txt": {
                "path": "/Users/aaronm/test-chunk-ds/587.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "588.txt": {
                "path": "/Users/aaronm/test-chunk-ds/588.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "589.txt": {
                "path": "/Users/aaronm/test-chunk-ds/589.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "59.txt": {
                "path": "/Users/aaronm/test-chunk-ds/59.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "590.txt": {
                "path": "/Users/aaronm/test-chunk-ds/590.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "591.txt": {
                "path": "/Users/aaronm/test-chunk-ds/591.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "592.txt": {
                "path": "/Users/aaronm/test-chunk-ds/592.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "593.txt": {
                "path": "/Users/aaronm/test-chunk-ds/593.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "594.txt": {
                "path": "/Users/aaronm/test-chunk-ds/594.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "595.txt": {
                "path": "/Users/aaronm/test-chunk-ds/595.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "596.txt": {
                "path": "/Users/aaronm/test-chunk-ds/596.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "597.txt": {
                "path": "/Users/aaronm/test-chunk-ds/597.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "598.txt": {
                "path": "/Users/aaronm/test-chunk-ds/598.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "599.txt": {
                "path": "/Users/aaronm/test-chunk-ds/599.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "6.txt": {
                "path": "/Users/aaronm/test-chunk-ds/6.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "60.txt": {
                "path": "/Users/aaronm/test-chunk-ds/60.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "600.txt": {
                "path": "/Users/aaronm/test-chunk-ds/600.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "601.txt": {
                "path": "/Users/aaronm/test-chunk-ds/601.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "602.txt": {
                "path": "/Users/aaronm/test-chunk-ds/602.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "603.txt": {
                "path": "/Users/aaronm/test-chunk-ds/603.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "604.txt": {
                "path": "/Users/aaronm/test-chunk-ds/604.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "605.txt": {
                "path": "/Users/aaronm/test-chunk-ds/605.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "606.txt": {
                "path": "/Users/aaronm/test-chunk-ds/606.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "607.txt": {
                "path": "/Users/aaronm/test-chunk-ds/607.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "608.txt": {
                "path": "/Users/aaronm/test-chunk-ds/608.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "609.txt": {
                "path": "/Users/aaronm/test-chunk-ds/609.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "61.txt": {
                "path": "/Users/aaronm/test-chunk-ds/61.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "610.txt": {
                "path": "/Users/aaronm/test-chunk-ds/610.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "611.txt": {
                "path": "/Users/aaronm/test-chunk-ds/611.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "612.txt": {
                "path": "/Users/aaronm/test-chunk-ds/612.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "613.txt": {
                "path": "/Users/aaronm/test-chunk-ds/613.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "614.txt": {
                "path": "/Users/aaronm/test-chunk-ds/614.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "615.txt": {
                "path": "/Users/aaronm/test-chunk-ds/615.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "616.txt": {
                "path": "/Users/aaronm/test-chunk-ds/616.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "617.txt": {
                "path": "/Users/aaronm/test-chunk-ds/617.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "618.txt": {
                "path": "/Users/aaronm/test-chunk-ds/618.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "619.txt": {
                "path": "/Users/aaronm/test-chunk-ds/619.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "62.txt": {
                "path": "/Users/aaronm/test-chunk-ds/62.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "620.txt": {
                "path": "/Users/aaronm/test-chunk-ds/620.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "621.txt": {
                "path": "/Users/aaronm/test-chunk-ds/621.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "622.txt": {
                "path": "/Users/aaronm/test-chunk-ds/622.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "623.txt": {
                "path": "/Users/aaronm/test-chunk-ds/623.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "624.txt": {
                "path": "/Users/aaronm/test-chunk-ds/624.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "625.txt": {
                "path": "/Users/aaronm/test-chunk-ds/625.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "626.txt": {
                "path": "/Users/aaronm/test-chunk-ds/626.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "627.txt": {
                "path": "/Users/aaronm/test-chunk-ds/627.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "628.txt": {
                "path": "/Users/aaronm/test-chunk-ds/628.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "629.txt": {
                "path": "/Users/aaronm/test-chunk-ds/629.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "63.txt": {
                "path": "/Users/aaronm/test-chunk-ds/63.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "630.txt": {
                "path": "/Users/aaronm/test-chunk-ds/630.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "631.txt": {
                "path": "/Users/aaronm/test-chunk-ds/631.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "632.txt": {
                "path": "/Users/aaronm/test-chunk-ds/632.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "633.txt": {
                "path": "/Users/aaronm/test-chunk-ds/633.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "634.txt": {
                "path": "/Users/aaronm/test-chunk-ds/634.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "635.txt": {
                "path": "/Users/aaronm/test-chunk-ds/635.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "636.txt": {
                "path": "/Users/aaronm/test-chunk-ds/636.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "637.txt": {
                "path": "/Users/aaronm/test-chunk-ds/637.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "638.txt": {
                "path": "/Users/aaronm/test-chunk-ds/638.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "639.txt": {
                "path": "/Users/aaronm/test-chunk-ds/639.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "64.txt": {
                "path": "/Users/aaronm/test-chunk-ds/64.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "640.txt": {
                "path": "/Users/aaronm/test-chunk-ds/640.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "641.txt": {
                "path": "/Users/aaronm/test-chunk-ds/641.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "642.txt": {
                "path": "/Users/aaronm/test-chunk-ds/642.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "643.txt": {
                "path": "/Users/aaronm/test-chunk-ds/643.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "644.txt": {
                "path": "/Users/aaronm/test-chunk-ds/644.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "645.txt": {
                "path": "/Users/aaronm/test-chunk-ds/645.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "646.txt": {
                "path": "/Users/aaronm/test-chunk-ds/646.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "647.txt": {
                "path": "/Users/aaronm/test-chunk-ds/647.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "648.txt": {
                "path": "/Users/aaronm/test-chunk-ds/648.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "649.txt": {
                "path": "/Users/aaronm/test-chunk-ds/649.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "65.txt": {
                "path": "/Users/aaronm/test-chunk-ds/65.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "650.txt": {
                "path": "/Users/aaronm/test-chunk-ds/650.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "651.txt": {
                "path": "/Users/aaronm/test-chunk-ds/651.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "652.txt": {
                "path": "/Users/aaronm/test-chunk-ds/652.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "653.txt": {
                "path": "/Users/aaronm/test-chunk-ds/653.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "654.txt": {
                "path": "/Users/aaronm/test-chunk-ds/654.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "655.txt": {
                "path": "/Users/aaronm/test-chunk-ds/655.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "656.txt": {
                "path": "/Users/aaronm/test-chunk-ds/656.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "657.txt": {
                "path": "/Users/aaronm/test-chunk-ds/657.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "658.txt": {
                "path": "/Users/aaronm/test-chunk-ds/658.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "659.txt": {
                "path": "/Users/aaronm/test-chunk-ds/659.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "66.txt": {
                "path": "/Users/aaronm/test-chunk-ds/66.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "660.txt": {
                "path": "/Users/aaronm/test-chunk-ds/660.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "661.txt": {
                "path": "/Users/aaronm/test-chunk-ds/661.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "662.txt": {
                "path": "/Users/aaronm/test-chunk-ds/662.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "663.txt": {
                "path": "/Users/aaronm/test-chunk-ds/663.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "664.txt": {
                "path": "/Users/aaronm/test-chunk-ds/664.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "665.txt": {
                "path": "/Users/aaronm/test-chunk-ds/665.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "666.txt": {
                "path": "/Users/aaronm/test-chunk-ds/666.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "667.txt": {
                "path": "/Users/aaronm/test-chunk-ds/667.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "668.txt": {
                "path": "/Users/aaronm/test-chunk-ds/668.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "669.txt": {
                "path": "/Users/aaronm/test-chunk-ds/669.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "67.txt": {
                "path": "/Users/aaronm/test-chunk-ds/67.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "670.txt": {
                "path": "/Users/aaronm/test-chunk-ds/670.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "671.txt": {
                "path": "/Users/aaronm/test-chunk-ds/671.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "672.txt": {
                "path": "/Users/aaronm/test-chunk-ds/672.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "673.txt": {
                "path": "/Users/aaronm/test-chunk-ds/673.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "674.txt": {
                "path": "/Users/aaronm/test-chunk-ds/674.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "675.txt": {
                "path": "/Users/aaronm/test-chunk-ds/675.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "676.txt": {
                "path": "/Users/aaronm/test-chunk-ds/676.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "677.txt": {
                "path": "/Users/aaronm/test-chunk-ds/677.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "678.txt": {
                "path": "/Users/aaronm/test-chunk-ds/678.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "679.txt": {
                "path": "/Users/aaronm/test-chunk-ds/679.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "68.txt": {
                "path": "/Users/aaronm/test-chunk-ds/68.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "680.txt": {
                "path": "/Users/aaronm/test-chunk-ds/680.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "681.txt": {
                "path": "/Users/aaronm/test-chunk-ds/681.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "682.txt": {
                "path": "/Users/aaronm/test-chunk-ds/682.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "683.txt": {
                "path": "/Users/aaronm/test-chunk-ds/683.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "684.txt": {
                "path": "/Users/aaronm/test-chunk-ds/684.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "685.txt": {
                "path": "/Users/aaronm/test-chunk-ds/685.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "686.txt": {
                "path": "/Users/aaronm/test-chunk-ds/686.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "687.txt": {
                "path": "/Users/aaronm/test-chunk-ds/687.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "688.txt": {
                "path": "/Users/aaronm/test-chunk-ds/688.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "689.txt": {
                "path": "/Users/aaronm/test-chunk-ds/689.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "69.txt": {
                "path": "/Users/aaronm/test-chunk-ds/69.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "690.txt": {
                "path": "/Users/aaronm/test-chunk-ds/690.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "691.txt": {
                "path": "/Users/aaronm/test-chunk-ds/691.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "692.txt": {
                "path": "/Users/aaronm/test-chunk-ds/692.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "693.txt": {
                "path": "/Users/aaronm/test-chunk-ds/693.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "694.txt": {
                "path": "/Users/aaronm/test-chunk-ds/694.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "695.txt": {
                "path": "/Users/aaronm/test-chunk-ds/695.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "696.txt": {
                "path": "/Users/aaronm/test-chunk-ds/696.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "697.txt": {
                "path": "/Users/aaronm/test-chunk-ds/697.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "698.txt": {
                "path": "/Users/aaronm/test-chunk-ds/698.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "699.txt": {
                "path": "/Users/aaronm/test-chunk-ds/699.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "7.txt": {
                "path": "/Users/aaronm/test-chunk-ds/7.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "70.txt": {
                "path": "/Users/aaronm/test-chunk-ds/70.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "700.txt": {
                "path": "/Users/aaronm/test-chunk-ds/700.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "701.txt": {
                "path": "/Users/aaronm/test-chunk-ds/701.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "702.txt": {
                "path": "/Users/aaronm/test-chunk-ds/702.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "703.txt": {
                "path": "/Users/aaronm/test-chunk-ds/703.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "704.txt": {
                "path": "/Users/aaronm/test-chunk-ds/704.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "705.txt": {
                "path": "/Users/aaronm/test-chunk-ds/705.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "706.txt": {
                "path": "/Users/aaronm/test-chunk-ds/706.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "707.txt": {
                "path": "/Users/aaronm/test-chunk-ds/707.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "708.txt": {
                "path": "/Users/aaronm/test-chunk-ds/708.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "709.txt": {
                "path": "/Users/aaronm/test-chunk-ds/709.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "71.txt": {
                "path": "/Users/aaronm/test-chunk-ds/71.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "710.txt": {
                "path": "/Users/aaronm/test-chunk-ds/710.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "711.txt": {
                "path": "/Users/aaronm/test-chunk-ds/711.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "712.txt": {
                "path": "/Users/aaronm/test-chunk-ds/712.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "713.txt": {
                "path": "/Users/aaronm/test-chunk-ds/713.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "714.txt": {
                "path": "/Users/aaronm/test-chunk-ds/714.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "715.txt": {
                "path": "/Users/aaronm/test-chunk-ds/715.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "716.txt": {
                "path": "/Users/aaronm/test-chunk-ds/716.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "717.txt": {
                "path": "/Users/aaronm/test-chunk-ds/717.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "718.txt": {
                "path": "/Users/aaronm/test-chunk-ds/718.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "719.txt": {
                "path": "/Users/aaronm/test-chunk-ds/719.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "72.txt": {
                "path": "/Users/aaronm/test-chunk-ds/72.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "720.txt": {
                "path": "/Users/aaronm/test-chunk-ds/720.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "721.txt": {
                "path": "/Users/aaronm/test-chunk-ds/721.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "722.txt": {
                "path": "/Users/aaronm/test-chunk-ds/722.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "723.txt": {
                "path": "/Users/aaronm/test-chunk-ds/723.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "724.txt": {
                "path": "/Users/aaronm/test-chunk-ds/724.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "725.txt": {
                "path": "/Users/aaronm/test-chunk-ds/725.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "726.txt": {
                "path": "/Users/aaronm/test-chunk-ds/726.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "727.txt": {
                "path": "/Users/aaronm/test-chunk-ds/727.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "728.txt": {
                "path": "/Users/aaronm/test-chunk-ds/728.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "729.txt": {
                "path": "/Users/aaronm/test-chunk-ds/729.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "73.txt": {
                "path": "/Users/aaronm/test-chunk-ds/73.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "730.txt": {
                "path": "/Users/aaronm/test-chunk-ds/730.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "731.txt": {
                "path": "/Users/aaronm/test-chunk-ds/731.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "732.txt": {
                "path": "/Users/aaronm/test-chunk-ds/732.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "733.txt": {
                "path": "/Users/aaronm/test-chunk-ds/733.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "734.txt": {
                "path": "/Users/aaronm/test-chunk-ds/734.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "735.txt": {
                "path": "/Users/aaronm/test-chunk-ds/735.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "736.txt": {
                "path": "/Users/aaronm/test-chunk-ds/736.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "737.txt": {
                "path": "/Users/aaronm/test-chunk-ds/737.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "738.txt": {
                "path": "/Users/aaronm/test-chunk-ds/738.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "739.txt": {
                "path": "/Users/aaronm/test-chunk-ds/739.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "74.txt": {
                "path": "/Users/aaronm/test-chunk-ds/74.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "740.txt": {
                "path": "/Users/aaronm/test-chunk-ds/740.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "741.txt": {
                "path": "/Users/aaronm/test-chunk-ds/741.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "742.txt": {
                "path": "/Users/aaronm/test-chunk-ds/742.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "743.txt": {
                "path": "/Users/aaronm/test-chunk-ds/743.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "744.txt": {
                "path": "/Users/aaronm/test-chunk-ds/744.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "745.txt": {
                "path": "/Users/aaronm/test-chunk-ds/745.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "746.txt": {
                "path": "/Users/aaronm/test-chunk-ds/746.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "747.txt": {
                "path": "/Users/aaronm/test-chunk-ds/747.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "748.txt": {
                "path": "/Users/aaronm/test-chunk-ds/748.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "749.txt": {
                "path": "/Users/aaronm/test-chunk-ds/749.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "75.txt": {
                "path": "/Users/aaronm/test-chunk-ds/75.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "750.txt": {
                "path": "/Users/aaronm/test-chunk-ds/750.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "751.txt": {
                "path": "/Users/aaronm/test-chunk-ds/751.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "752.txt": {
                "path": "/Users/aaronm/test-chunk-ds/752.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "753.txt": {
                "path": "/Users/aaronm/test-chunk-ds/753.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "754.txt": {
                "path": "/Users/aaronm/test-chunk-ds/754.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "755.txt": {
                "path": "/Users/aaronm/test-chunk-ds/755.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "756.txt": {
                "path": "/Users/aaronm/test-chunk-ds/756.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "757.txt": {
                "path": "/Users/aaronm/test-chunk-ds/757.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "758.txt": {
                "path": "/Users/aaronm/test-chunk-ds/758.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "759.txt": {
                "path": "/Users/aaronm/test-chunk-ds/759.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "76.txt": {
                "path": "/Users/aaronm/test-chunk-ds/76.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "760.txt": {
                "path": "/Users/aaronm/test-chunk-ds/760.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "761.txt": {
                "path": "/Users/aaronm/test-chunk-ds/761.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "762.txt": {
                "path": "/Users/aaronm/test-chunk-ds/762.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "763.txt": {
                "path": "/Users/aaronm/test-chunk-ds/763.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "764.txt": {
                "path": "/Users/aaronm/test-chunk-ds/764.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "765.txt": {
                "path": "/Users/aaronm/test-chunk-ds/765.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "766.txt": {
                "path": "/Users/aaronm/test-chunk-ds/766.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "767.txt": {
                "path": "/Users/aaronm/test-chunk-ds/767.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "768.txt": {
                "path": "/Users/aaronm/test-chunk-ds/768.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "769.txt": {
                "path": "/Users/aaronm/test-chunk-ds/769.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "77.txt": {
                "path": "/Users/aaronm/test-chunk-ds/77.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "770.txt": {
                "path": "/Users/aaronm/test-chunk-ds/770.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "771.txt": {
                "path": "/Users/aaronm/test-chunk-ds/771.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "772.txt": {
                "path": "/Users/aaronm/test-chunk-ds/772.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "773.txt": {
                "path": "/Users/aaronm/test-chunk-ds/773.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "774.txt": {
                "path": "/Users/aaronm/test-chunk-ds/774.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "775.txt": {
                "path": "/Users/aaronm/test-chunk-ds/775.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "776.txt": {
                "path": "/Users/aaronm/test-chunk-ds/776.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "777.txt": {
                "path": "/Users/aaronm/test-chunk-ds/777.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "778.txt": {
                "path": "/Users/aaronm/test-chunk-ds/778.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "779.txt": {
                "path": "/Users/aaronm/test-chunk-ds/779.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "78.txt": {
                "path": "/Users/aaronm/test-chunk-ds/78.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "780.txt": {
                "path": "/Users/aaronm/test-chunk-ds/780.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "781.txt": {
                "path": "/Users/aaronm/test-chunk-ds/781.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "782.txt": {
                "path": "/Users/aaronm/test-chunk-ds/782.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "783.txt": {
                "path": "/Users/aaronm/test-chunk-ds/783.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "784.txt": {
                "path": "/Users/aaronm/test-chunk-ds/784.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "785.txt": {
                "path": "/Users/aaronm/test-chunk-ds/785.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "786.txt": {
                "path": "/Users/aaronm/test-chunk-ds/786.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "787.txt": {
                "path": "/Users/aaronm/test-chunk-ds/787.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "788.txt": {
                "path": "/Users/aaronm/test-chunk-ds/788.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "789.txt": {
                "path": "/Users/aaronm/test-chunk-ds/789.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "79.txt": {
                "path": "/Users/aaronm/test-chunk-ds/79.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "790.txt": {
                "path": "/Users/aaronm/test-chunk-ds/790.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "791.txt": {
                "path": "/Users/aaronm/test-chunk-ds/791.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "792.txt": {
                "path": "/Users/aaronm/test-chunk-ds/792.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "793.txt": {
                "path": "/Users/aaronm/test-chunk-ds/793.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "794.txt": {
                "path": "/Users/aaronm/test-chunk-ds/794.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "795.txt": {
                "path": "/Users/aaronm/test-chunk-ds/795.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "796.txt": {
                "path": "/Users/aaronm/test-chunk-ds/796.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "797.txt": {
                "path": "/Users/aaronm/test-chunk-ds/797.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "798.txt": {
                "path": "/Users/aaronm/test-chunk-ds/798.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "799.txt": {
                "path": "/Users/aaronm/test-chunk-ds/799.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "8.txt": {
                "path": "/Users/aaronm/test-chunk-ds/8.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "80.txt": {
                "path": "/Users/aaronm/test-chunk-ds/80.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "800.txt": {
                "path": "/Users/aaronm/test-chunk-ds/800.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "801.txt": {
                "path": "/Users/aaronm/test-chunk-ds/801.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "802.txt": {
                "path": "/Users/aaronm/test-chunk-ds/802.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "803.txt": {
                "path": "/Users/aaronm/test-chunk-ds/803.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "804.txt": {
                "path": "/Users/aaronm/test-chunk-ds/804.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "805.txt": {
                "path": "/Users/aaronm/test-chunk-ds/805.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "806.txt": {
                "path": "/Users/aaronm/test-chunk-ds/806.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "807.txt": {
                "path": "/Users/aaronm/test-chunk-ds/807.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "808.txt": {
                "path": "/Users/aaronm/test-chunk-ds/808.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "809.txt": {
                "path": "/Users/aaronm/test-chunk-ds/809.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "81.txt": {
                "path": "/Users/aaronm/test-chunk-ds/81.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "810.txt": {
                "path": "/Users/aaronm/test-chunk-ds/810.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "811.txt": {
                "path": "/Users/aaronm/test-chunk-ds/811.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "812.txt": {
                "path": "/Users/aaronm/test-chunk-ds/812.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "813.txt": {
                "path": "/Users/aaronm/test-chunk-ds/813.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "814.txt": {
                "path": "/Users/aaronm/test-chunk-ds/814.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "815.txt": {
                "path": "/Users/aaronm/test-chunk-ds/815.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "816.txt": {
                "path": "/Users/aaronm/test-chunk-ds/816.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "817.txt": {
                "path": "/Users/aaronm/test-chunk-ds/817.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "818.txt": {
                "path": "/Users/aaronm/test-chunk-ds/818.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "819.txt": {
                "path": "/Users/aaronm/test-chunk-ds/819.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "82.txt": {
                "path": "/Users/aaronm/test-chunk-ds/82.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "820.txt": {
                "path": "/Users/aaronm/test-chunk-ds/820.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "821.txt": {
                "path": "/Users/aaronm/test-chunk-ds/821.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "822.txt": {
                "path": "/Users/aaronm/test-chunk-ds/822.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "823.txt": {
                "path": "/Users/aaronm/test-chunk-ds/823.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "824.txt": {
                "path": "/Users/aaronm/test-chunk-ds/824.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "825.txt": {
                "path": "/Users/aaronm/test-chunk-ds/825.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "826.txt": {
                "path": "/Users/aaronm/test-chunk-ds/826.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "827.txt": {
                "path": "/Users/aaronm/test-chunk-ds/827.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "828.txt": {
                "path": "/Users/aaronm/test-chunk-ds/828.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "829.txt": {
                "path": "/Users/aaronm/test-chunk-ds/829.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "83.txt": {
                "path": "/Users/aaronm/test-chunk-ds/83.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "830.txt": {
                "path": "/Users/aaronm/test-chunk-ds/830.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "831.txt": {
                "path": "/Users/aaronm/test-chunk-ds/831.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "832.txt": {
                "path": "/Users/aaronm/test-chunk-ds/832.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "833.txt": {
                "path": "/Users/aaronm/test-chunk-ds/833.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "834.txt": {
                "path": "/Users/aaronm/test-chunk-ds/834.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "835.txt": {
                "path": "/Users/aaronm/test-chunk-ds/835.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "836.txt": {
                "path": "/Users/aaronm/test-chunk-ds/836.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "837.txt": {
                "path": "/Users/aaronm/test-chunk-ds/837.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "838.txt": {
                "path": "/Users/aaronm/test-chunk-ds/838.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "839.txt": {
                "path": "/Users/aaronm/test-chunk-ds/839.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "84.txt": {
                "path": "/Users/aaronm/test-chunk-ds/84.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "840.txt": {
                "path": "/Users/aaronm/test-chunk-ds/840.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "841.txt": {
                "path": "/Users/aaronm/test-chunk-ds/841.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "842.txt": {
                "path": "/Users/aaronm/test-chunk-ds/842.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "843.txt": {
                "path": "/Users/aaronm/test-chunk-ds/843.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "844.txt": {
                "path": "/Users/aaronm/test-chunk-ds/844.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "845.txt": {
                "path": "/Users/aaronm/test-chunk-ds/845.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "846.txt": {
                "path": "/Users/aaronm/test-chunk-ds/846.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "847.txt": {
                "path": "/Users/aaronm/test-chunk-ds/847.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "848.txt": {
                "path": "/Users/aaronm/test-chunk-ds/848.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "849.txt": {
                "path": "/Users/aaronm/test-chunk-ds/849.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "85.txt": {
                "path": "/Users/aaronm/test-chunk-ds/85.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "850.txt": {
                "path": "/Users/aaronm/test-chunk-ds/850.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "851.txt": {
                "path": "/Users/aaronm/test-chunk-ds/851.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "852.txt": {
                "path": "/Users/aaronm/test-chunk-ds/852.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "853.txt": {
                "path": "/Users/aaronm/test-chunk-ds/853.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "854.txt": {
                "path": "/Users/aaronm/test-chunk-ds/854.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "855.txt": {
                "path": "/Users/aaronm/test-chunk-ds/855.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "856.txt": {
                "path": "/Users/aaronm/test-chunk-ds/856.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "857.txt": {
                "path": "/Users/aaronm/test-chunk-ds/857.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "858.txt": {
                "path": "/Users/aaronm/test-chunk-ds/858.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "859.txt": {
                "path": "/Users/aaronm/test-chunk-ds/859.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "86.txt": {
                "path": "/Users/aaronm/test-chunk-ds/86.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "860.txt": {
                "path": "/Users/aaronm/test-chunk-ds/860.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "861.txt": {
                "path": "/Users/aaronm/test-chunk-ds/861.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "862.txt": {
                "path": "/Users/aaronm/test-chunk-ds/862.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "863.txt": {
                "path": "/Users/aaronm/test-chunk-ds/863.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "864.txt": {
                "path": "/Users/aaronm/test-chunk-ds/864.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "865.txt": {
                "path": "/Users/aaronm/test-chunk-ds/865.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "866.txt": {
                "path": "/Users/aaronm/test-chunk-ds/866.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "867.txt": {
                "path": "/Users/aaronm/test-chunk-ds/867.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "868.txt": {
                "path": "/Users/aaronm/test-chunk-ds/868.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "869.txt": {
                "path": "/Users/aaronm/test-chunk-ds/869.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "87.txt": {
                "path": "/Users/aaronm/test-chunk-ds/87.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "870.txt": {
                "path": "/Users/aaronm/test-chunk-ds/870.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "871.txt": {
                "path": "/Users/aaronm/test-chunk-ds/871.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "872.txt": {
                "path": "/Users/aaronm/test-chunk-ds/872.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "873.txt": {
                "path": "/Users/aaronm/test-chunk-ds/873.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "874.txt": {
                "path": "/Users/aaronm/test-chunk-ds/874.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "875.txt": {
                "path": "/Users/aaronm/test-chunk-ds/875.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "876.txt": {
                "path": "/Users/aaronm/test-chunk-ds/876.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "877.txt": {
                "path": "/Users/aaronm/test-chunk-ds/877.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "878.txt": {
                "path": "/Users/aaronm/test-chunk-ds/878.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "879.txt": {
                "path": "/Users/aaronm/test-chunk-ds/879.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "88.txt": {
                "path": "/Users/aaronm/test-chunk-ds/88.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "880.txt": {
                "path": "/Users/aaronm/test-chunk-ds/880.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "881.txt": {
                "path": "/Users/aaronm/test-chunk-ds/881.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "882.txt": {
                "path": "/Users/aaronm/test-chunk-ds/882.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "883.txt": {
                "path": "/Users/aaronm/test-chunk-ds/883.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "884.txt": {
                "path": "/Users/aaronm/test-chunk-ds/884.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "885.txt": {
                "path": "/Users/aaronm/test-chunk-ds/885.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "886.txt": {
                "path": "/Users/aaronm/test-chunk-ds/886.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "887.txt": {
                "path": "/Users/aaronm/test-chunk-ds/887.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "888.txt": {
                "path": "/Users/aaronm/test-chunk-ds/888.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "889.txt": {
                "path": "/Users/aaronm/test-chunk-ds/889.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "89.txt": {
                "path": "/Users/aaronm/test-chunk-ds/89.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "890.txt": {
                "path": "/Users/aaronm/test-chunk-ds/890.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "891.txt": {
                "path": "/Users/aaronm/test-chunk-ds/891.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "892.txt": {
                "path": "/Users/aaronm/test-chunk-ds/892.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "893.txt": {
                "path": "/Users/aaronm/test-chunk-ds/893.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "894.txt": {
                "path": "/Users/aaronm/test-chunk-ds/894.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "895.txt": {
                "path": "/Users/aaronm/test-chunk-ds/895.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "896.txt": {
                "path": "/Users/aaronm/test-chunk-ds/896.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "897.txt": {
                "path": "/Users/aaronm/test-chunk-ds/897.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "898.txt": {
                "path": "/Users/aaronm/test-chunk-ds/898.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "899.txt": {
                "path": "/Users/aaronm/test-chunk-ds/899.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "9.txt": {
                "path": "/Users/aaronm/test-chunk-ds/9.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "90.txt": {
                "path": "/Users/aaronm/test-chunk-ds/90.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "900.txt": {
                "path": "/Users/aaronm/test-chunk-ds/900.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "901.txt": {
                "path": "/Users/aaronm/test-chunk-ds/901.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "902.txt": {
                "path": "/Users/aaronm/test-chunk-ds/902.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "903.txt": {
                "path": "/Users/aaronm/test-chunk-ds/903.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "904.txt": {
                "path": "/Users/aaronm/test-chunk-ds/904.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "905.txt": {
                "path": "/Users/aaronm/test-chunk-ds/905.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "906.txt": {
                "path": "/Users/aaronm/test-chunk-ds/906.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "907.txt": {
                "path": "/Users/aaronm/test-chunk-ds/907.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "908.txt": {
                "path": "/Users/aaronm/test-chunk-ds/908.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "909.txt": {
                "path": "/Users/aaronm/test-chunk-ds/909.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "91.txt": {
                "path": "/Users/aaronm/test-chunk-ds/91.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "910.txt": {
                "path": "/Users/aaronm/test-chunk-ds/910.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "911.txt": {
                "path": "/Users/aaronm/test-chunk-ds/911.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "912.txt": {
                "path": "/Users/aaronm/test-chunk-ds/912.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "913.txt": {
                "path": "/Users/aaronm/test-chunk-ds/913.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "914.txt": {
                "path": "/Users/aaronm/test-chunk-ds/914.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "915.txt": {
                "path": "/Users/aaronm/test-chunk-ds/915.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "916.txt": {
                "path": "/Users/aaronm/test-chunk-ds/916.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "917.txt": {
                "path": "/Users/aaronm/test-chunk-ds/917.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "918.txt": {
                "path": "/Users/aaronm/test-chunk-ds/918.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "919.txt": {
                "path": "/Users/aaronm/test-chunk-ds/919.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "92.txt": {
                "path": "/Users/aaronm/test-chunk-ds/92.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "920.txt": {
                "path": "/Users/aaronm/test-chunk-ds/920.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "921.txt": {
                "path": "/Users/aaronm/test-chunk-ds/921.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "922.txt": {
                "path": "/Users/aaronm/test-chunk-ds/922.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "923.txt": {
                "path": "/Users/aaronm/test-chunk-ds/923.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "924.txt": {
                "path": "/Users/aaronm/test-chunk-ds/924.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "925.txt": {
                "path": "/Users/aaronm/test-chunk-ds/925.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "926.txt": {
                "path": "/Users/aaronm/test-chunk-ds/926.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "927.txt": {
                "path": "/Users/aaronm/test-chunk-ds/927.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "928.txt": {
                "path": "/Users/aaronm/test-chunk-ds/928.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "929.txt": {
                "path": "/Users/aaronm/test-chunk-ds/929.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "93.txt": {
                "path": "/Users/aaronm/test-chunk-ds/93.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "930.txt": {
                "path": "/Users/aaronm/test-chunk-ds/930.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "931.txt": {
                "path": "/Users/aaronm/test-chunk-ds/931.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "932.txt": {
                "path": "/Users/aaronm/test-chunk-ds/932.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "933.txt": {
                "path": "/Users/aaronm/test-chunk-ds/933.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "934.txt": {
                "path": "/Users/aaronm/test-chunk-ds/934.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "935.txt": {
                "path": "/Users/aaronm/test-chunk-ds/935.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "936.txt": {
                "path": "/Users/aaronm/test-chunk-ds/936.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "937.txt": {
                "path": "/Users/aaronm/test-chunk-ds/937.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "938.txt": {
                "path": "/Users/aaronm/test-chunk-ds/938.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "939.txt": {
                "path": "/Users/aaronm/test-chunk-ds/939.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "94.txt": {
                "path": "/Users/aaronm/test-chunk-ds/94.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "940.txt": {
                "path": "/Users/aaronm/test-chunk-ds/940.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "941.txt": {
                "path": "/Users/aaronm/test-chunk-ds/941.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "942.txt": {
                "path": "/Users/aaronm/test-chunk-ds/942.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "943.txt": {
                "path": "/Users/aaronm/test-chunk-ds/943.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "944.txt": {
                "path": "/Users/aaronm/test-chunk-ds/944.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "945.txt": {
                "path": "/Users/aaronm/test-chunk-ds/945.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "946.txt": {
                "path": "/Users/aaronm/test-chunk-ds/946.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "947.txt": {
                "path": "/Users/aaronm/test-chunk-ds/947.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "948.txt": {
                "path": "/Users/aaronm/test-chunk-ds/948.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "949.txt": {
                "path": "/Users/aaronm/test-chunk-ds/949.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "95.txt": {
                "path": "/Users/aaronm/test-chunk-ds/95.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "950.txt": {
                "path": "/Users/aaronm/test-chunk-ds/950.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "951.txt": {
                "path": "/Users/aaronm/test-chunk-ds/951.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "952.txt": {
                "path": "/Users/aaronm/test-chunk-ds/952.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "953.txt": {
                "path": "/Users/aaronm/test-chunk-ds/953.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "954.txt": {
                "path": "/Users/aaronm/test-chunk-ds/954.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "955.txt": {
                "path": "/Users/aaronm/test-chunk-ds/955.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "956.txt": {
                "path": "/Users/aaronm/test-chunk-ds/956.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "957.txt": {
                "path": "/Users/aaronm/test-chunk-ds/957.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "958.txt": {
                "path": "/Users/aaronm/test-chunk-ds/958.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "959.txt": {
                "path": "/Users/aaronm/test-chunk-ds/959.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "96.txt": {
                "path": "/Users/aaronm/test-chunk-ds/96.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "960.txt": {
                "path": "/Users/aaronm/test-chunk-ds/960.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "961.txt": {
                "path": "/Users/aaronm/test-chunk-ds/961.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "962.txt": {
                "path": "/Users/aaronm/test-chunk-ds/962.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "963.txt": {
                "path": "/Users/aaronm/test-chunk-ds/963.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "964.txt": {
                "path": "/Users/aaronm/test-chunk-ds/964.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "965.txt": {
                "path": "/Users/aaronm/test-chunk-ds/965.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "966.txt": {
                "path": "/Users/aaronm/test-chunk-ds/966.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "967.txt": {
                "path": "/Users/aaronm/test-chunk-ds/967.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "968.txt": {
                "path": "/Users/aaronm/test-chunk-ds/968.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "969.txt": {
                "path": "/Users/aaronm/test-chunk-ds/969.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "97.txt": {
                "path": "/Users/aaronm/test-chunk-ds/97.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "970.txt": {
                "path": "/Users/aaronm/test-chunk-ds/970.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "971.txt": {
                "path": "/Users/aaronm/test-chunk-ds/971.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "972.txt": {
                "path": "/Users/aaronm/test-chunk-ds/972.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "973.txt": {
                "path": "/Users/aaronm/test-chunk-ds/973.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "974.txt": {
                "path": "/Users/aaronm/test-chunk-ds/974.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "975.txt": {
                "path": "/Users/aaronm/test-chunk-ds/975.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "976.txt": {
                "path": "/Users/aaronm/test-chunk-ds/976.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "977.txt": {
                "path": "/Users/aaronm/test-chunk-ds/977.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "978.txt": {
                "path": "/Users/aaronm/test-chunk-ds/978.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "979.txt": {
                "path": "/Users/aaronm/test-chunk-ds/979.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "98.txt": {
                "path": "/Users/aaronm/test-chunk-ds/98.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "980.txt": {
                "path": "/Users/aaronm/test-chunk-ds/980.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "981.txt": {
                "path": "/Users/aaronm/test-chunk-ds/981.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "982.txt": {
                "path": "/Users/aaronm/test-chunk-ds/982.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "983.txt": {
                "path": "/Users/aaronm/test-chunk-ds/983.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "984.txt": {
                "path": "/Users/aaronm/test-chunk-ds/984.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "985.txt": {
                "path": "/Users/aaronm/test-chunk-ds/985.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "986.txt": {
                "path": "/Users/aaronm/test-chunk-ds/986.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "987.txt": {
                "path": "/Users/aaronm/test-chunk-ds/987.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "988.txt": {
                "path": "/Users/aaronm/test-chunk-ds/988.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "989.txt": {
                "path": "/Users/aaronm/test-chunk-ds/989.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "99.txt": {
                "path": "/Users/aaronm/test-chunk-ds/99.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "990.txt": {
                "path": "/Users/aaronm/test-chunk-ds/990.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "991.txt": {
                "path": "/Users/aaronm/test-chunk-ds/991.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "992.txt": {
                "path": "/Users/aaronm/test-chunk-ds/992.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "993.txt": {
                "path": "/Users/aaronm/test-chunk-ds/993.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "994.txt": {
                "path": "/Users/aaronm/test-chunk-ds/994.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "995.txt": {
                "path": "/Users/aaronm/test-chunk-ds/995.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "996.txt": {
                "path": "/Users/aaronm/test-chunk-ds/996.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "997.txt": {
                "path": "/Users/aaronm/test-chunk-ds/997.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "998.txt": {
                "path": "/Users/aaronm/test-chunk-ds/998.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              },
              "999.txt": {
                "path": "/Users/aaronm/test-chunk-ds/999.txt",
                "description": "",
                "additional-metadata": "",
                "type": "local",
                "action": [
                  "new"
                ]
              }
            },
            "action": [
              "new"
            ]
          }
        },
        "files": {},
        "type": "",
        "action": []
      },
      "primary": {
        "folders": {},
        "files": {
          "0.txt": {
            "path": "/Users/aaronm/test-chunk-ds/0.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "1.txt": {
            "path": "/Users/aaronm/test-chunk-ds/1.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "2.txt": {
            "path": "/Users/aaronm/test-chunk-ds/2.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "3.txt": {
            "path": "/Users/aaronm/test-chunk-ds/3.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "4.txt": {
            "path": "/Users/aaronm/test-chunk-ds/4.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "5.txt": {
            "path": "/Users/aaronm/test-chunk-ds/5.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "6.txt": {
            "path": "/Users/aaronm/test-chunk-ds/6.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "7.txt": {
            "path": "/Users/aaronm/test-chunk-ds/7.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "8.txt": {
            "path": "/Users/aaronm/test-chunk-ds/8.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "9.txt": {
            "path": "/Users/aaronm/test-chunk-ds/9.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          },
          "10.txt": {
            "path": "/Users/aaronm/test-chunk-ds/10.txt",
            "type": "local",
            "description": "",
            "additional-metadata": "",
            "action": [
              "new"
            ]
          }
        },
        "type": "",
        "action": []
      }
    },
    "files": {}
  },
  "metadata-files": {
    "submission.xlsx": {
      "type": "bf",
      "action": [
        "existing"
      ],
      "path": "N:package:6a5343d5-3da9-4d49-baca-a62d0fe625c1"
    },
    "CHANGES.txt": {
      "type": "bf",
      "action": [
        "existing"
      ],
      "path": "N:package:f0c514c3-bd73-4e4c-8814-0b97b3f69556"
    },
    "README.txt": {
      "type": "bf",
      "action": [
        "existing"
      ],
      "path": "N:package:bd96b506-e79d-4b45-b342-35c881fbd5fc"
    }
  },
  "generate-dataset": {
    "destination": "bf",
    "generate-option": "existing-bf"
  },
  "starting-point": {
    "type": "bf"
  }
}

# %%
bf_recognized_file_extensions = [
    ".cram",
    ".jp2",
    ".jpx",
    ".lsm",
    ".ndpi",
    ".nifti",
    ".oib",
    ".oif",
    ".roi",
    ".rtf",
    ".swc",
    ".abf",
    ".acq",
    ".adicht",
    ".adidat",
    ".aedt",
    ".afni",
    ".ai",
    ".avi",
    ".bam",
    ".bash",
    ".bcl",
    ".bcl.gz",
    ".bin",
    ".brik",
    ".brukertiff.gz",
    ".continuous",
    ".cpp",
    ".csv",
    ".curv",
    ".cxls",
    ".czi",
    ".data",
    ".dcm",
    ".df",
    ".dicom",
    ".doc",
    ".docx",
    ".e",
    ".edf",
    ".eps",
    ".events",
    ".fasta",
    ".fastq",
    ".fcs",
    ".feather",
    ".fig",
    ".gif",
    ".h4",
    ".h5",
    ".hdf4",
    ".hdf5",
    ".hdr",
    ".he2",
    ".he5",
    ".head",
    ".hoc",
    ".htm",
    ".html",
    ".ibw",
    ".img",
    ".ims",
    ".ipynb",
    ".jpeg",
    ".jpg",
    ".js",
    ".json",
    ".lay",
    ".lh",
    ".lif",
    ".m",
    ".mat",
    ".md",
    ".mef",
    ".mefd.gz",
    ".mex",
    ".mgf",
    ".mgh",
    ".mgh.gz",
    ".mgz",
    ".mnc",
    ".moberg.gz",
    ".mod",
    ".mov",
    ".mp4",
    ".mph",
    ".mpj",
    ".mtw",
    ".ncs",
    ".nd2",
    ".nev",
    ".nex",
    ".nex5",
    ".nf3",
    ".nii",
    ".nii.gz",
    ".ns1",
    ".ns2",
    ".ns3",
    ".ns4",
    ".ns5",
    ".ns6",
    ".nwb",
    ".ogg",
    ".ogv",
    ".ome.btf",
    ".ome.tif",
    ".ome.tif2",
    ".ome.tif8",
    ".ome.tiff",
    ".ome.xml",
    ".openephys",
    ".pdf",
    ".pgf",
    ".png",
    ".ppt",
    ".pptx",
    ".ps",
    ".pul",
    ".py",
    ".r",
    ".raw",
    ".rdata",
    ".rh",
    ".rhd",
    ".sh",
    ".sldasm",
    ".slddrw",
    ".smr",
    ".spikes",
    ".svg",
    ".svs",
    ".tab",
    ".tar",
    ".tar.gz",
    ".tcsh",
    ".tdm",
    ".tdms",
    ".text",
    ".tif",
    ".tiff",
    ".tsv",
    ".txt",
    ".vcf",
    ".webm",
    ".xlsx",
    ".xml",
    ".yaml",
    ".yml",
    ".zip",
    ".zsh",
]

# %%
def get_base_file_name(file_name):
    output = []
    if file_name[-1] == ")":
        string_length = len(file_name)
        count_start = string_length
        character = file_name[count_start - 1]
        while character != "(" and count_start >= 0:
            count_start -= 1
            character = file_name[count_start - 1]
        if character == "(":
            base_name = file_name[0 : count_start - 1]
            num = file_name[count_start : string_length - 1]
            if check_if_int(num):
                output = [base_name, int(num)]
            return output
        else:
            return output

    else:
        return output

# %%
userpath = expanduser("~")

# path to local SODA folder for saving manifest files
manifest_sparc = ["manifest.xlsx", "manifest.csv"]
manifest_folder_path = join(userpath, "SODA", "manifest_files")

# %%
def check_forbidden_characters_bf(my_string):
    """
    Check for forbidden characters in Pennsieve file/folder name

    Args:
        my_string: string with characters (string)
    Returns:
        False: no forbidden character
        True: presence of forbidden character(s)
    """
    regex = re.compile("[" + forbidden_characters_bf + "]")
    if regex.search(my_string) == None and "\\" not in r"%r" % my_string:
        return False
    else:
        return True

# %%
def bf_dataset_size():
    """
    Function to get storage size of a dataset on Pennsieve
    """
    global bf
    global myds

    try:
        selected_dataset_id = myds.id
        bf_response = bf._api._get("/datasets/" + str(selected_dataset_id))
        return bf_response["storage"] if "storage" in bf_response.keys() else 0
    except Exception as e:
        raise e

# %%
def agent_running():
    listen_port = 11235

    try:
        # x = "ws://127.0.0.1:11235"
        # create_connection(x).close()
        # CHANGE BACK
        create_connection(socket_address(listen_port)).close()

    except socket.error as e:
        print(e)

        if e.errno == errno.ECONNREFUSED:  # ConnectionRefusedError for Python 3
            return True
        else:
            raise e
    else:
        raise AgentError(
            "The Pennsieve agent is already running. Learn more about how to solve the issue <a href='https://github.com/bvhpatel/SODA/wiki/The-Pennsieve-agent-is-already-running' target='_blank'>here</a>."
        )

# %%
def clear_queue():

    command = [agent_cmd(), "upload-status", "--cancel-all"]

    proc = subprocess.run(command, check=True)  # env=agent_env(?settings?)
    return proc

# %%
def generate_relative_path(x, y):
    if x:
        relative_path = x + "/" + y
    else:
        relative_path = y
    return relative_path

# %%
def bf_get_existing_files_details(bf_folder):

    double_extensions = [
        ".ome.tiff",
        ".ome.tif",
        ".ome.tf2,",
        ".ome.tf8",
        ".ome.btf",
        ".ome.xml",
        ".brukertiff.gz",
        ".mefd.gz",
        ".moberg.gz",
        ".nii.gz",
        ".mgh.gz",
        ".tar.gz",
        ".bcl.gz",
    ]

    # f = open("dataset_contents.soda", "a")

    def verify_file_name(file_name, extension):
        if extension == "":
            return file_name

        double_ext = False
        for ext in double_extensions:
            if file_name.find(ext) != -1:
                double_ext = True
                break

        extension_from_name = ""

        if double_ext == False:
            extension_from_name = os.path.splitext(file_name)[1]
        else:
            extension_from_name = (
                os.path.splitext(os.path.splitext(file_name)[0])[1]
                + os.path.splitext(file_name)[1]
            )

        if extension_from_name == ("." + extension):
            return file_name
        else:
            return file_name + ("." + extension)

    bf_existing_files = [x for x in bf_folder.items if x.type != "Collection"]
    bf_existing_files_name = [splitext(x.name)[0] for x in bf_existing_files]
    bf_existing_files_name_with_extension = []
    for file in bf_existing_files:
        file_name_with_extension = ""
        file_id = file.id
        file_details = bf._api._get("/packages/" + str(file_id))
        # file_name_with_extension = verify_file_name(file_details["content"]["name"], file_details["extension"])
        if "extension" not in file_details:
            file_name_with_extension = verify_file_name(
                file_details["content"]["name"], ""
            )
        else:
            file_name_with_extension = verify_file_name(
                file_details["content"]["name"], file_details["extension"]
            )

        # file_extension = splitext(file_name_with_extension)[1]
        # file_name_with_extension = splitext(file.name)[0] + file_extension
        bf_existing_files_name_with_extension.append(file_name_with_extension)

    return (
        bf_existing_files,
        bf_existing_files_name,
        bf_existing_files_name_with_extension,
    )

# %%
def bf_get_existing_folders_details(bf_folder):
    bf_existing_folders = [x for x in bf_folder.items if x.type == "Collection"]
    bf_existing_folders_name = [x.name for x in bf_existing_folders]

    return bf_existing_folders, bf_existing_folders_name

# %%
def bf_get_dataset_files_folders(soda_json_structure, requested_sparc_only=True):
    """
    Function for importing Pennsieve data files info into the "dataset-structure" key of the soda json structure,
    including metadata from any existing manifest files in the high-level folders
    (name, id, timestamp, description, additional metadata)

    Args:
        soda_json_structure: soda structure with bf account and dataset info available
    Output:
        same soda structure with Pennsieve data file info included under the "dataset-structure" key
    """

    high_level_sparc_folders = [
        "code",
        "derivative",
        "docs",
        "primary",
        "protocol",
        "source",
    ]
    manifest_sparc = ["manifest.xlsx", "manifest.csv"]
    high_level_metadata_sparc = [
        "submission.xlsx",
        "submission.csv",
        "submission.json",
        "dataset_description.xlsx",
        "dataset_description.csv",
        "dataset_description.json",
        "subjects.xlsx",
        "subjects.csv",
        "subjects.json",
        "samples.xlsx",
        "samples.csv",
        "samples.json",
        "README.txt",
        "CHANGES.txt",
        "code_description.xlsx",
        "inputs_metadata.xlsx",
        "outputs_metadata.xlsx",
    ]
    manifest_error_message = []
    double_extensions = [
        ".ome.tiff",
        ".ome.tif",
        ".ome.tf2,",
        ".ome.tf8",
        ".ome.btf",
        ".ome.xml",
        ".brukertiff.gz",
        ".mefd.gz",
        ".moberg.gz",
        ".nii.gz",
        ".mgh.gz",
        ".tar.gz",
        ".bcl.gz",
    ]

    # f = open("dataset_contents.soda", "a")

    def verify_file_name(file_name, extension):
        if extension == "":
            return file_name

        double_ext = False
        for ext in double_extensions:
            if file_name.find(ext) != -1:
                double_ext = True
                break

        extension_from_name = ""

        if double_ext == False:
            extension_from_name = os.path.splitext(file_name)[1]
        else:
            extension_from_name = (
                os.path.splitext(os.path.splitext(file_name)[0])[1]
                + os.path.splitext(file_name)[1]
            )

        if extension_from_name == ("." + extension):
            return file_name
        else:
            return file_name + ("." + extension)

    # Add a new key containing the path to all the files and folders on the
    # local data structure..
    def recursive_item_path_create(folder, path):
        if "files" in folder.keys():
            for item in list(folder["files"]):
                if "bfpath" not in folder["files"][item]:
                    folder["files"][item]["bfpath"] = path[:]

        if "folders" in folder.keys():
            for item in list(folder["folders"]):
                if "bfpath" not in folder["folders"][item]:
                    folder["folders"][item]["bfpath"] = path[:]
                    folder["folders"][item]["bfpath"].append(item)
                recursive_item_path_create(
                    folder["folders"][item], folder["folders"][item]["bfpath"][:]
                )
        return

    level = 0

    def recursive_dataset_import(
        my_item, dataset_folder, metadata_files, my_folder_name, my_level, manifest_dict
    ):
        level = 0
        col_count = 0
        file_count = 0

        for item in my_item:
            if item.type == "Collection":
                if "folders" not in dataset_folder:
                    dataset_folder["folders"] = {}
                if "files" not in dataset_folder:
                    dataset_folder["files"] = {}
                col_count += 1
                folder_name = item.name
                if (
                    my_level == 0
                    and folder_name not in high_level_sparc_folders
                    and requested_sparc_only
                ):  # only import SPARC folders
                    col_count -= 1
                    continue
                if col_count == 1:
                    level = my_level + 1
                dataset_folder["folders"][folder_name] = {
                    "type": "bf",
                    "action": ["existing"],
                    "path": item.id,
                }
                sub_folder = dataset_folder["folders"][folder_name]
                if "folders" not in sub_folder:
                    sub_folder["folders"] = {}
                if "files" not in sub_folder:
                    sub_folder["files"] = {}
                recursive_dataset_import(
                    item, sub_folder, metadata_files, folder_name, level, manifest_dict
                )
            else:
                if "folders" not in dataset_folder:
                    dataset_folder["folders"] = {}
                if "files" not in dataset_folder:
                    dataset_folder["files"] = {}
                package_id = item.id
                package_details = bf._api._get("/packages/" + str(package_id))
                if "extension" not in package_details:
                    file_name = verify_file_name(package_details["content"]["name"], "")
                else:
                    file_name = verify_file_name(
                        package_details["content"]["name"], package_details["extension"]
                    )

                if my_level == 0 and file_name in high_level_metadata_sparc:
                    metadata_files[file_name] = {
                        "type": "bf",
                        "action": ["existing"],
                        "path": item.id,
                    }

                else:
                    file_count += 1
                    if my_level == 1 and file_name in manifest_sparc:
                        file_details = bf._api._get(
                            "/packages/" + str(package_id) + "/view"
                        )
                        file_id = file_details[0]["content"]["id"]
                        manifest_url = bf._api._get(
                            "/packages/" + str(package_id) + "/files/" + str(file_id)
                        )
                        df = ""
                        try:
                            if file_name.lower() == "manifest.xlsx":
                                df = pd.read_excel(
                                    manifest_url["url"], engine="openpyxl"
                                )
                            else:
                                df = pd.read_csv(manifest_url["url"])
                            manifest_dict[my_folder_name] = df
                        except Exception as e:
                            manifest_error_message.append(
                                package_details["parent"]["content"]["name"]
                            )
                            pass
                    else:
                        timestamp = (
                            package_details["content"]["createdAt"]
                            .replace(".", ",")
                            .replace("+00:00", "Z")
                        )
                        dataset_folder["files"][file_name] = {
                            "type": "bf",
                            "action": ["existing"],
                            "path": item.id,
                            "timestamp": timestamp,
                        }

    def recursive_manifest_info_import(my_folder, my_relative_path, manifest_df):

        if "files" in my_folder.keys():
            for file_key, file in my_folder["files"].items():
                filename = join(my_relative_path, file_key)
                colum_headers = manifest_df.columns.tolist()
                filename = filename.replace("\\", "/")

                if filename in list(manifest_df["filename"].values):
                    if "description" in colum_headers:
                        mydescription = manifest_df[
                            manifest_df["filename"] == filename
                        ]["description"].values[0]
                        if mydescription:
                            file["description"] = mydescription
                    if "Additional Metadata" in colum_headers:
                        my_additional_medata = manifest_df[
                            manifest_df["filename"] == filename
                        ]["Additional Metadata"].values[0]
                        if my_additional_medata:
                            file["additional-metadata"] = my_additional_medata
                    if "timestamp" in colum_headers:
                        my_timestamp = manifest_df[manifest_df["filename"] == filename][
                            "timestamp"
                        ].values[0]
                        if my_timestamp:
                            file["timestamp"] = my_timestamp

        if "folders" in my_folder.keys():
            for folder_key, folder in my_folder["folders"].items():
                relative_path = join(my_relative_path, folder_key)

                recursive_manifest_info_import(folder, relative_path, manifest_df)

    # START

    error = []

    # check that the Pennsieve account is valid
    try:
        bf_account_name = soda_json_structure["bf-account-selected"]["account-name"]
    except Exception as e:
        raise e

    try:
        bf = Pennsieve(bf_account_name)
    except Exception as e:
        error.append("Error: Please select a valid Pennsieve account")
        raise Exception(error)

    # check that the Pennsieve dataset is valid
    try:
        bf_dataset_name = soda_json_structure["bf-dataset-selected"]["dataset-name"]
    except Exception as e:
        raise e
    try:
        myds = bf.get_dataset(bf_dataset_name)
    except Exception as e:
        error.append("Error: Please select a valid Pennsieve dataset")
        raise Exception(error)

    # check that the user has permission to edit this dataset
    try:
        role = bf_get_current_user_permission(bf, myds)
        if role not in ["owner", "manager", "editor"]:
            curatestatus = "Done"
            error.append(
                "Error: You don't have permissions for uploading to this Pennsieve dataset"
            )
            raise Exception(error)
    except Exception as e:
        raise e

    try:
        # import files and folders in the soda json structure
        soda_json_structure["dataset-structure"] = {}
        soda_json_structure["metadata-files"] = {}
        dataset_folder = soda_json_structure["dataset-structure"]
        metadata_files = soda_json_structure["metadata-files"]
        manifest_dict = {}
        folder_name = ""
        recursive_dataset_import(
            myds, dataset_folder, metadata_files, folder_name, level, manifest_dict
        )

        # remove metadata files keys if empty
        metadata_files = soda_json_structure["metadata-files"]
        if not metadata_files:
            del soda_json_structure["metadata-files"]

        dataset_folder = soda_json_structure["dataset-structure"]
        # pull information from the manifest files if they satisfy the SPARC format
        if "folders" in dataset_folder.keys():
            for folder_key in manifest_dict.keys():
                manifest_df = manifest_dict[folder_key]
                manifest_df = manifest_df.fillna("")
                colum_headers = manifest_df.columns.tolist()
                folder = dataset_folder["folders"][folder_key]
                if "filename" in colum_headers:
                    if (
                        "description" in colum_headers
                        or "Additional Metadata" in colum_headers
                    ):
                        relative_path = ""
                        recursive_manifest_info_import(
                            folder, relative_path, manifest_df
                        )

        recursive_item_path_create(soda_json_structure["dataset-structure"], [])
        success_message = (
            "Data files under a valid high-level SPARC folders have been imported"
        )
        return [soda_json_structure, success_message, manifest_error_message]

    except Exception as e:
        raise e

# %%
def bf_get_current_user_permission(bf, myds):

    """
    Function to get the permission of currently logged in user for a selected dataset

    Args:
        bf: logged Pennsieve acccount (dict)
        myds: selected Pennsieve dataset (dict)
    Output:
        permission of current user (string)
    """

    try:
        selected_dataset_id = myds.id
        user_role = bf._api._get("/datasets/" + str(selected_dataset_id) + "/role")[
            "role"
        ]

        return user_role

    except Exception as e:
        raise e

# %%
def check_local_dataset_files_validity(soda_json_structure):
    """
    Function to check that the local data files and folders specified in the dataset are valid

    Args:
        soda_json_structure: soda dict with information about all specified files and folders
    Output:
        error: error message with list of non valid local data files, if any
    """

    def recursive_local_file_check(my_folder, my_relative_path, error):
        for folder_key, folder in my_folder["folders"].items():
            relative_path = my_relative_path + "/" + folder_key
            error = recursive_local_file_check(folder, relative_path, error)

        for file_key in list(my_folder["files"].keys()):
            file = my_folder["files"][file_key]
            file_type = file["type"]
            if file_type == "local":
                file_path = file["path"]
                if file["type"] == "bf":
                    continue
                if not isfile(file_path):
                    relative_path = my_relative_path + "/" + file_key
                    error_message = relative_path + " (path: " + file_path + ")"
                    error.append(error_message)
                else:
                    file_size = getsize(file_path)
                    if file_size == 0:
                        del my_folder["files"][file_key]

        return error

    def recursive_empty_local_folder_remove(
        my_folder, my_folder_key, my_folders_content
    ):

        folders_content = my_folder["folders"]
        for folder_key in list(my_folder["folders"].keys()):
            folder = my_folder["folders"][folder_key]
            recursive_empty_local_folder_remove(folder, folder_key, folders_content)

        if not my_folder["folders"]:
            if not my_folder["files"]:
                if my_folder["type"] != "bf":
                    del my_folders_content[my_folder_key]

    error = []
    if "dataset-structure" in soda_json_structure.keys():
        dataset_structure = soda_json_structure["dataset-structure"]
        if "folders" in dataset_structure:
            for folder_key, folder in dataset_structure["folders"].items():
                relative_path = folder_key
                error = recursive_local_file_check(folder, relative_path, error)

            folders_content = dataset_structure["folders"]
            for folder_key in list(dataset_structure["folders"].keys()):
                folder = dataset_structure["folders"][folder_key]
                recursive_empty_local_folder_remove(folder, folder_key, folders_content)

    if "metadata-files" in soda_json_structure.keys():
        metadata_files = soda_json_structure["metadata-files"]
        for file_key in list(metadata_files.keys()):
            file = metadata_files[file_key]
            file_type = file["type"]
            if file_type == "local":
                file_path = file["path"]
                if not isfile(file_path):
                    error_message = file_key + " (path: " + file_path + ")"
                    error.append(error_message)
                else:
                    file_size = getsize(file_path)
                    if file_size == 0:
                        del metadata_files[file_key]
        if not metadata_files:
            del soda_json_structure["metadata-files"]

    if len(error) > 0:
        error_message = [
            "Error: The following local files were not found. Specify them again or remove them."
        ]
        error = error_message + error

    return error

# %%
# checks if a dataset that will be uploaded to Pennsieve has a valid structure
def bf_check_dataset_files_validity(soda_json_structure, bf):
    """
    Function to check that the bf data files and folders specified in the dataset are valid

    Args:
        dataset_structure: soda dict with information about all specified files and folders
    Output:
        error: error message with list of non valid local data files, if any
    """

    def recursive_bf_dataset_check(my_folder, my_relative_path, error):
        if "folders" in my_folder.keys():
            for folder_key, folder in my_folder["folders"].items():
                folder_type = folder["type"]
                relative_path = my_relative_path + "/" + folder_key
                if folder_type == "bf":
                    package_id = folder["path"]
                    try:
                        details = bf._api._get("/packages/" + str(package_id) + "/view")
                    except Exception as e:
                        error_message = relative_path + " (id: " + package_id + ")"
                        error.append(error_message)
                        pass
                error = recursive_bf_dataset_check(folder, relative_path, error)
        if "files" in my_folder.keys():
            for file_key, file in my_folder["files"].items():
                file_type = file["type"]
                if file_type == "bf":
                    package_id = file["path"]
                    try:
                        details = bf._api._get("/packages/" + str(package_id) + "/view")
                    except Exception as e:
                        relative_path = my_relative_path + "/" + file_key
                        error_message = relative_path + " (id: " + package_id + ")"
                        error.append(error_message)
                        pass

        return error

    error = []
    if "dataset-structure" in soda_json_structure.keys():
        dataset_structure = soda_json_structure["dataset-structure"]
        if "folders" in dataset_structure:
            for folder_key, folder in dataset_structure["folders"].items():
                folder_type = folder["type"]
                relative_path = folder_key
                if folder_type == "bf":
                    package_id = folder["path"]
                    try:
                        details = bf._api._get("/packages/" + str(package_id) + "/view")
                    except Exception as e:
                        error_message = relative_path + " (id: " + package_id + ")"
                        error.append(error_message)
                        pass
                error = recursive_bf_dataset_check(folder, relative_path, error)
        if "files" in dataset_structure:
            for file_key, file in dataset_structure["files"].items():
                file_type = file["type"]
                if file_type == "bf":
                    package_id = folder["path"]
                    try:
                        details = bf._api._get("/packages/" + str(package_id) + "/view")
                    except Exception as e:
                        relative_path = file_key
                        error_message = relative_path + " (id: " + package_id + ")"
                        error.append(error_message)
                        pass

    if "metadata-files" in soda_json_structure:
        metadata_files = soda_json_structure["metadata-files"]
        for file_key, file in metadata_files.items():
            file_type = file["type"]
            if file_type == "bf":
                package_id = file["path"]
                try:
                    details = bf._api._get("/packages/" + str(package_id) + "/view")
                except Exception as e:
                    error_message = file_key + " (id: " + package_id + ")"
                    error.append(error_message)
                    pass

    if len(error) > 0:
        error_message = [
            "Error: The following Pennsieve files/folders are invalid. Specify them again or remove them."
        ]
        error = error_message + error

    return error

# %%
# the main curate function works off of the SODA JSON object and uses the below to methods 
# to upload a dataset to Pennsieve
def main_curate_function(soda_json_structure):

    global main_curate_status
    global main_curate_progress_message
    global main_total_generate_dataset_size
    global main_generated_dataset_size
    global start_generate
    global generate_start_time
    global main_generate_destination
    global main_initial_bfdataset_size
    # global progress_percentage
    # global progress_percentage_array

    global bf
    global myds

    start_generate = 0
    generate_start_time = time.time()

    main_curate_status = ""
    main_curate_progress_message = "Starting..."
    main_total_generate_dataset_size = 1
    main_generated_dataset_size = 0

    main_curate_status = "Curating"
    main_curate_progress_message = "Starting dataset curation"
    # progress_percentage = "000.0%"
    # progress_percentage_array = []
    main_generate_destination = ""
    main_initial_bfdataset_size = 0
    bf = ""
    myds = ""

    main_keys = soda_json_structure.keys()
    error = ""
    
    print(soda_json_structure["generate-dataset"])

    # 1] Check for potential errors

    # 1.1. Check that the local destination is valid if generate dataset locally is requested
    if "generate-dataset" in main_keys:
        if soda_json_structure["generate-dataset"]["destination"] == "local":
            main_curate_progress_message = "Checking that the local destination selected for generating your dataset is valid"
            generate_dataset = soda_json_structure["generate-dataset"]
            local_dataset_path = generate_dataset["path"]
            # if generate_dataset["if-existing"] == "merge":
            #     local_dataset_path = join(local_dataset_path, generate_dataset["dataset-name"])
            if not isdir(local_dataset_path):
                error_message = (
                    "Error: The Path "
                    + local_dataset_path
                    + " is not found. Please select a valid destination folder for the new dataset"
                )
                main_curate_status = "Done"
                error = error_message
                raise Exception(error)

    # 1.2. Check that the bf destination is valid if generate on bf, or any other bf actions are requested
    if "bf-account-selected" in soda_json_structure:
        # check that the Pennsieve account is valid
        try:
            main_curate_progress_message = (
                "Checking that the selected Pennsieve account is valid"
            )
            accountname = soda_json_structure["bf-account-selected"]["account-name"]
            bf = Pennsieve(accountname)
        except Exception as e:
            main_curate_status = "Done"
            error = "Error: Please select a valid Pennsieve account"
            raise Exception(error)

    # if uploading on an existing bf dataset
    if "bf-dataset-selected" in soda_json_structure:
        # check that the Pennsieve dataset is valid
        try:
            main_curate_progress_message = (
                "Checking that the selected Pennsieve dataset is valid"
            )
            bfdataset = soda_json_structure["bf-dataset-selected"]["dataset-name"]
            myds = bf.get_dataset(bfdataset)
        except Exception as e:
            main_curate_status = "Done"
            error = "Error: Please select a valid Pennsieve dataset"
            raise Exception(error)

        # check that the user has permissions for uploading and modifying the dataset
        try:
            main_curate_progress_message = "Checking that you have required permissions for modifying the selected dataset"
            role = bf_get_current_user_permission(bf, myds)
            if role not in ["owner", "manager", "editor"]:
                main_curate_status = "Done"
                error = "Error: You don't have permissions for uploading to this Pennsieve dataset"
                raise Exception(error)
        except Exception as e:
            raise e

    # 1.3. Check that specified dataset files and folders are valid (existing path) if generate dataset is requested
    # Note: Empty folders and 0 kb files will be removed without warning (a warning will be provided on the front end before starting the curate process)
    if "generate-dataset" in main_keys:

        # Check at least one file or folder are added to the dataset
        try:
            main_curate_progress_message = "Checking that the dataset is not empty"
            if (
                "dataset-structure" not in soda_json_structure
                and "metadata-files" not in soda_json_structure
            ):
                main_curate_status = "Done"
                error = "Error: Your dataset is empty. Please add valid files and non-empty folders to your dataset."
                raise Exception(error)
        except Exception as e:
            main_curate_status = "Done"
            raise Exception(e)

        # Check that local files/folders exist
        try:

            error = check_local_dataset_files_validity(soda_json_structure)
            if error:
                main_curate_status = "Done"
                raise Exception(error)

            # check that dataset is not empty after removing all the empty files and folders
            if (
                not soda_json_structure["dataset-structure"]["folders"]
                and not "metadata-files" in soda_json_structure
            ):
                main_curate_status = "Done"
                error = "Error: Your dataset is empty. Please add valid files and non-empty folders to your dataset."
                raise Exception(error)

        except Exception as e:
            main_curate_status = "Done"
            raise e

        # Check that bf files/folders exist
        print(soda_json_structure["generate-dataset"])
        generate_option = soda_json_structure["generate-dataset"]["generate-option"]
        print(generate_option)
        if generate_option == "existing-bf":
            try:
                main_curate_progress_message = (
                    "Checking that the Pennsieve files and folders are valid"
                )
                if soda_json_structure["generate-dataset"]["destination"] == "bf":
                    error = bf_check_dataset_files_validity(soda_json_structure, bf)
                    if error:
                        main_curate_status = "Done"
                        raise Exception(error)
            except Exception as e:
                main_curate_status = "Done"
                raise e

    # 3] Generate
    if "generate-dataset" in main_keys:
        main_curate_progress_message = "Generating dataset"
        try:
            if soda_json_structure["generate-dataset"]["destination"] == "local":
                main_generate_destination = soda_json_structure["generate-dataset"][
                    "destination"
                ]
                _, main_total_generate_dataset_size = generate_dataset_locally(
                    soda_json_structure
                )
                # if "manifest-files" in main_keys:
                #     main_curate_progress_message = "Generating manifest files"
                #     add_local_manifest_files(manifest_files_structure, datasetpath)

            if soda_json_structure["generate-dataset"]["destination"] == "bf":
                main_generate_destination = soda_json_structure["generate-dataset"][
                    "destination"
                ]
                if generate_option == "new":
                    if "dataset-name" in soda_json_structure["generate-dataset"]:
                        dataset_name = soda_json_structure["generate-dataset"][
                            "dataset-name"
                        ]
                        myds = bf_create_new_dataset(dataset_name, bf)
                    bf_generate_new_dataset(soda_json_structure, bf, myds)
                    # if "manifest-files" in main_keys:
                    #     main_curate_progress_message = "Generating manifest files"
                    #     bf_add_manifest_files(manifest_files_structure, myds)
                if generate_option == "existing-bf":
                    myds = bf.get_dataset(bfdataset)
                    bf_update_existing_dataset(soda_json_structure, bf, myds)

        except Exception as e:
            main_curate_status = "Done"
            raise e

    main_curate_status = "Done"
    main_curate_progress_message = "Success: COMPLETED!"

    return main_curate_progress_message, main_total_generate_dataset_size

# %%
def bf_update_existing_dataset(soda_json_structure, bf, ds):
    global main_curate_progress_message
    global main_total_generate_dataset_size
    global start_generate
    global main_initial_bfdataset_size
    # global progress_percentage
    # global progress_percentage_array
    bfsd = ""

    # Delete any files on Pennsieve that have been marked as deleted
    def recursive_file_delete(folder):
        if "files" in folder.keys():
            for item in list(folder["files"]):
                if "deleted" in folder["files"][item]["action"]:
                    file = bf.get(folder["files"][item]["path"])
                    file.delete()
                    del folder["files"][item]

        for item in list(folder["folders"]):
            recursive_file_delete(folder["folders"][item])
        return

    # Delete any files on Pennsieve that have been marked as deleted
    def metadata_file_delete(soda_json_structure):
        if "metadata-files" in soda_json_structure.keys():
            folder = soda_json_structure["metadata-files"]
            for item in list(folder):
                if "deleted" in folder[item]["action"]:
                    file = bf.get(folder[item]["path"])
                    file.delete()
                    del folder[item]

        return

    # Add a new key containing the path to all the files and folders on the
    # local data structure.
    # Allows us to see if the folder path of a specfic file already
    # exists on Pennsieve.
    def recursive_item_path_create(folder, path):
        if "files" in folder.keys():
            for item in list(folder["files"]):
                if "folderpath" not in folder["files"][item]:
                    folder["files"][item]["folderpath"] = path[:]

        if "folders" in folder.keys():
            for item in list(folder["folders"]):
                if "folderpath" not in folder["folders"][item]:
                    folder["folders"][item]["folderpath"] = path[:]
                    folder["folders"][item]["folderpath"].append(item)
                recursive_item_path_create(
                    folder["folders"][item], folder["folders"][item]["folderpath"][:]
                )

        return

    # Check and create any non existing folders for the file move process
    def recursive_check_and_create_bf_file_path(
        folderpath, index, current_folder_structure
    ):
        folder = folderpath[index]

        if folder not in current_folder_structure["folders"]:
            if index == 0:
                new_folder = ds.create_collection(folder)
            else:
                current_folder = bf.get(current_folder_structure["path"])
                new_folder = current_folder.create_collection(folder)
            current_folder_structure["folders"][folder] = {
                "type": "bf",
                "action": ["existing"],
                "path": new_folder.id,
                "folders": {},
                "files": {},
            }

        index += 1

        if index < len(folderpath):
            return recursive_check_and_create_bf_file_path(
                folderpath, index, current_folder_structure["folders"][folder]
            )
        else:
            return current_folder_structure["folders"][folder]["path"]

    # Check for any files that have been moved and verify paths before moving
    def recursive_check_moved_files(folder):
        if "files" in folder.keys():
            for item in list(folder["files"]):
                if (
                    "moved" in folder["files"][item]["action"]
                    and folder["files"][item]["type"] == "bf"
                ):
                    new_folder_id = ""
                    new_folder_id = recursive_check_and_create_bf_file_path(
                        folder["files"][item]["folderpath"].copy(), 0, bfsd
                    )
                    destination_folder = bf.get(new_folder_id)
                    bf.move(destination_folder, folder["files"][item]["path"])

        for item in list(folder["folders"]):
            recursive_check_moved_files(folder["folders"][item])

        return

    # Rename any files that exist on Pennsieve
    def recursive_file_rename(folder):
        if "files" in folder.keys():
            for item in list(folder["files"]):
                if (
                    "renamed" in folder["files"][item]["action"]
                    and folder["files"][item]["type"] == "bf"
                ):
                    file = bf.get(folder["files"][item]["path"])
                    if file is not None:
                        file.name = item
                        file.update()

        for item in list(folder["folders"]):
            recursive_file_rename(folder["folders"][item])

        return

    # Delete any stray folders that exist on Pennsieve
    # Only top level files are deleted since the api deletes any
    # files and folders that exist inside.
    def recursive_folder_delete(folder):
        for item in list(folder["folders"]):
            if folder["folders"][item]["type"] == "bf":
                if "moved" in folder["folders"][item]["action"]:
                    file = bf.get(folder["folders"][item]["path"])
                    if file is not None:
                        file.delete()
                if "deleted" in folder["folders"][item]["action"]:
                    file = bf.get(folder["folders"][item]["path"])
                    if file is not None:
                        file.delete()
                    del folder["folders"][item]
                else:
                    recursive_folder_delete(folder["folders"][item])
            else:
                recursive_folder_delete(folder["folders"][item])

        return

    # Rename any folders that still exist.
    def recursive_folder_rename(folder, mode):
        for item in list(folder["folders"]):
            if (
                folder["folders"][item]["type"] == "bf"
                and "action" in folder["folders"][item].keys()
            ):
                if mode in folder["folders"][item]["action"]:
                    file = bf.get(folder["folders"][item]["path"])
                    if file is not None:
                        file.name = item
                        file.update()
            recursive_folder_rename(folder["folders"][item], mode)

        return

    # 1. Remove all existing files on Pennsieve, that the user deleted.
    main_curate_progress_message = "Checking Pennsieve for deleted files"
    dataset_structure = soda_json_structure["dataset-structure"]
    recursive_file_delete(dataset_structure)
    main_curate_progress_message = (
        "Files on Pennsieve marked for deletion have been deleted"
    )

    # 2. Rename any deleted folders on Pennsieve to allow for replacements.
    main_curate_progress_message = "Checking Pennsieve for deleted folders"
    dataset_structure = soda_json_structure["dataset-structure"]
    recursive_folder_rename(dataset_structure, "deleted")
    main_curate_progress_message = "Folders on Pennsieve have been marked for deletion"

    # 2.5 Rename folders that need to be in the final destination.
    main_curate_progress_message = "Renaming any folders requested by the user"
    recursive_folder_rename(dataset_structure, "renamed")
    main_curate_progress_message = "Renamed all folders requested by the user"

    # 3. Get the status of all files currently on Pennsieve and create
    # the folderpath for all items in both dataset structures.
    main_curate_progress_message = "Fetching files and folders from Pennsieve"
    current_bf_dataset_files_folders = bf_get_dataset_files_folders(
        soda_json_structure.copy()
    )[0]
    bfsd = current_bf_dataset_files_folders["dataset-structure"]
    main_curate_progress_message = "Creating file paths for all files on Pennsieve"
    recursive_item_path_create(dataset_structure, [])
    recursive_item_path_create(bfsd, [])
    main_curate_progress_message = "File paths created"

    # 4. Move any files that are marked as moved on Pennsieve.
    # Create any additional folders if required
    main_curate_progress_message = "Moving any files requested by the user"
    recursive_check_moved_files(dataset_structure)
    main_curate_progress_message = "Moved all files requested by the user"

    # 5. Rename any Pennsieve files that are marked as renamed.
    main_curate_progress_message = "Renaming any files requested by the user"
    recursive_file_rename(dataset_structure)
    main_curate_progress_message = "Renamed all files requested by the user"

    # 6. Delete any Pennsieve folders that are marked as deleted.
    main_curate_progress_message = (
        "Deleting any additional folders present on Pennsieve"
    )
    recursive_folder_delete(dataset_structure)
    main_curate_progress_message = "Deletion of additional folders complete"

    # 7. Rename any Pennsieve folders that are marked as renamed.
    main_curate_progress_message = "Renaming any folders requested by the user"
    recursive_folder_rename(dataset_structure, "renamed")
    main_curate_progress_message = "Renamed all folders requested by the user"

    # 8. Delete any metadata files that are marked as deleted.
    main_curate_progress_message = "Removing any metadata files marked for deletion"
    metadata_file_delete(soda_json_structure)
    main_curate_progress_message = "Removed metadata files marked for deletion"

    # 9. Run the original code to upload any new files added to the dataset.
    if "manifest-files" in soda_json_structure.keys():
        soda_json_structure["manifest-files"] = {"destination": "bf"}

    soda_json_structure["generate-dataset"] = {
        "destination": "bf",
        "if-existing": "merge",
        "if-existing-files": "replace",
    }

    bfdataset = soda_json_structure["bf-dataset-selected"]["dataset-name"]
    myds = bf.get_dataset(bfdataset)
    bf_generate_new_dataset(soda_json_structure, bf, myds)

    return

# %%
def bf_generate_new_dataset(soda_json_structure, bf, ds):

    global main_curate_progress_message
    global main_total_generate_dataset_size
    global start_generate
    global main_initial_bfdataset_size
    # global progress_percentage
    # global progress_percentage_array

    try:

        def recursive_create_folder_for_bf(
            my_folder, my_tracking_folder, existing_folder_option
        ):

            # list of existing bf folders at this level
            my_bf_folder = my_tracking_folder["value"]
            (
                my_bf_existing_folders,
                my_bf_existing_folders_name,
            ) = bf_get_existing_folders_details(my_bf_folder)

            # create/replace/skip folder
            if "folders" in my_folder.keys():
                my_tracking_folder["folders"] = {}
                for folder_key, folder in my_folder["folders"].items():

                    if existing_folder_option == "skip":
                        if folder_key in my_bf_existing_folders_name:
                            continue
                        else:
                            bf_folder = my_bf_folder.create_collection(folder_key)

                    elif existing_folder_option == "create-duplicate":
                        bf_folder = my_bf_folder.create_collection(folder_key)

                    elif existing_folder_option == "replace":
                        if folder_key in my_bf_existing_folders_name:
                            index_folder = my_bf_existing_folders_name.index(folder_key)
                            bf_folder_delete = my_bf_existing_folders[index_folder]
                            bf_folder_delete.delete()
                            my_bf_folder.update()
                        bf_folder = my_bf_folder.create_collection(folder_key)

                    elif existing_folder_option == "merge":
                        if folder_key in my_bf_existing_folders_name:
                            index_folder = my_bf_existing_folders_name.index(folder_key)
                            bf_folder = my_bf_existing_folders[index_folder]
                        else:
                            bf_folder = my_bf_folder.create_collection(folder_key)
                    bf_folder.update()
                    my_tracking_folder["folders"][folder_key] = {"value": bf_folder}
                    tracking_folder = my_tracking_folder["folders"][folder_key]
                    recursive_create_folder_for_bf(
                        folder, tracking_folder, existing_folder_option
                    )

        def recursive_dataset_scan_for_bf(
            my_folder,
            my_tracking_folder,
            existing_file_option,
            list_upload_files,
            my_relative_path,
        ):

            global main_total_generate_dataset_size

            my_bf_folder = my_tracking_folder["value"]

            if "folders" in my_folder.keys():
                (
                    my_bf_existing_folders,
                    my_bf_existing_folders_name,
                ) = bf_get_existing_folders_details(my_bf_folder)

                for folder_key, folder in my_folder["folders"].items():
                    relative_path = generate_relative_path(my_relative_path, folder_key)

                    if existing_folder_option == "skip":
                        if folder_key not in my_tracking_folder["folders"].keys():
                            continue

                    tracking_folder = my_tracking_folder["folders"][folder_key]
                    list_upload_files = recursive_dataset_scan_for_bf(
                        folder,
                        tracking_folder,
                        existing_file_option,
                        list_upload_files,
                        relative_path,
                    )

            if "files" in my_folder.keys():

                # delete files to be deleted
                (
                    my_bf_existing_files,
                    my_bf_existing_files_name,
                    my_bf_existing_files_name_with_extension,
                ) = bf_get_existing_files_details(my_bf_folder)
                for file_key, file in my_folder["files"].items():
                    if file["type"] == "local":
                        file_path = file["path"]
                        if isfile(file_path):
                            if existing_file_option == "replace":
                                if file_key in my_bf_existing_files_name_with_extension:
                                    index_file = (
                                        my_bf_existing_files_name_with_extension.index(
                                            file_key
                                        )
                                    )
                                    my_file = my_bf_existing_files[index_file]
                                    my_file.delete()
                                    my_bf_folder.update()

                # create list of files to be uploaded with projected and desired names saved
                (
                    my_bf_existing_files,
                    my_bf_existing_files_name,
                    my_bf_existing_files_name_with_extension,
                ) = bf_get_existing_files_details(my_bf_folder)

                list_local_files = []
                list_projected_names = []
                list_desired_names = []
                list_final_names = []
                additional_upload_lists = []
                additional_list_count = 0
                list_upload_schedule_projected_names = []
                list_initial_names = []
                for file_key, file in my_folder["files"].items():
                    if file["type"] == "local":
                        file_path = file["path"]
                        if isfile(file_path):
                            initial_name = splitext(basename(file_path))[0]
                            initial_extension = splitext(basename(file_path))[1]
                            initial_name_with_extension = basename(file_path)
                            desired_name = splitext(file_key)[0]
                            desired_name_extension = splitext(file_key)[1]
                            desired_name_with_extension = file_key
                            # desired_name = file_key

                            if existing_file_option == "skip":
                                if file_key in my_bf_existing_files_name_with_extension:
                                    continue

                            # check if initial filename exists on Pennsieve dataset and get the projected name of the file after upload
                            count_done = 0
                            count_exist = 0
                            projected_name = initial_name_with_extension
                            while count_done == 0:
                                if (
                                    projected_name
                                    in my_bf_existing_files_name_with_extension
                                ):
                                    count_exist += 1
                                    projected_name = (
                                        initial_name
                                        + " ("
                                        + str(count_exist)
                                        + ")"
                                        + initial_extension
                                    )
                                else:
                                    count_done = 1

                            # expected final name
                            count_done = 0
                            final_name = desired_name_with_extension
                            output = get_base_file_name(desired_name)
                            if output:
                                base_name = output[0]
                                count_exist = output[1]
                                while count_done == 0:
                                    if final_name in my_bf_existing_files_name:
                                        count_exist += 1
                                        final_name = (
                                            base_name
                                            + "("
                                            + str(count_exist)
                                            + ")"
                                            + desired_name_extension
                                        )
                                    else:
                                        count_done = 1
                            else:
                                count_exist = 0
                                while count_done == 0:
                                    if final_name in my_bf_existing_files_name:
                                        count_exist += 1
                                        final_name = (
                                            desired_name
                                            + " ("
                                            + str(count_exist)
                                            + ")"
                                            + desired_name_extension
                                        )
                                    else:
                                        count_done = 1

                            # save in list accordingly
                            if (
                                initial_name in list_initial_names
                                or initial_name in list_final_names
                                or projected_name in list_final_names
                                or final_name in list_projected_names
                            ):
                                additional_upload_lists.append(
                                    [
                                        [file_path],
                                        my_bf_folder,
                                        [projected_name],
                                        [desired_name],
                                        [final_name],
                                        my_tracking_folder,
                                        my_relative_path,
                                    ]
                                )
                            else:
                                list_local_files.append(file_path)
                                list_projected_names.append(projected_name)
                                list_desired_names.append(desired_name_with_extension)
                                list_final_names.append(final_name)
                                list_initial_names.append(initial_name)

                            my_bf_existing_files_name.append(final_name)
                            if initial_extension in bf_recognized_file_extensions:
                                my_bf_existing_files_name_with_extension.append(
                                    final_name
                                )
                            else:
                                my_bf_existing_files_name_with_extension.append(
                                    final_name + initial_extension
                                )

                            # add to projected dataset size to be generated
                            main_total_generate_dataset_size += getsize(file_path)

                if list_local_files:
                    list_upload_files.append(
                        [
                            list_local_files,
                            my_bf_folder,
                            list_projected_names,
                            list_desired_names,
                            list_final_names,
                            my_tracking_folder,
                            my_relative_path,
                        ]
                    )

                for item in additional_upload_lists:
                    list_upload_files.append(item)

            return list_upload_files

        # 1. Scan the dataset structure to create all non-existent folders
        # create a tracking dict which would track the generation of the dataset on Pennsieve
        main_curate_progress_message = "Creating folder structure"
        dataset_structure = soda_json_structure["dataset-structure"]
        tracking_json_structure = {"value": ds}
        existing_folder_option = soda_json_structure["generate-dataset"]["if-existing"]
        recursive_create_folder_for_bf(
            dataset_structure, tracking_json_structure, existing_folder_option
        )

        # 2. Scan the dataset structure and compile a list of files to be uploaded along with desired renaming
        ds.update()
        main_curate_progress_message = "Preparing a list of files to upload"
        existing_file_option = soda_json_structure["generate-dataset"][
            "if-existing-files"
        ]
        list_upload_files = []
        relative_path = ds.name
        list_upload_files = recursive_dataset_scan_for_bf(
            dataset_structure,
            tracking_json_structure,
            existing_file_option,
            list_upload_files,
            relative_path,
        )

        # 3. Add high-level metadata files to a list
        ds.update()
        list_upload_metadata_files = []
        if "metadata-files" in soda_json_structure.keys():

            (
                my_bf_existing_files,
                my_bf_existing_files_name,
                my_bf_existing_files_name_with_extension,
            ) = bf_get_existing_files_details(ds)
            metadata_files = soda_json_structure["metadata-files"]
            for file_key, file in metadata_files.items():
                if file["type"] == "local":
                    metadata_path = file["path"]
                    if isfile(metadata_path):
                        initial_name = splitext(basename(metadata_path))[0]
                        if existing_file_option == "replace":
                            if initial_name in my_bf_existing_files_name:
                                index_file = my_bf_existing_files_name.index(
                                    initial_name
                                )
                                my_file = my_bf_existing_files[index_file]
                                my_file.delete()

                        if existing_file_option == "skip":
                            if initial_name in my_bf_existing_files_name:
                                continue

                        list_upload_metadata_files.append(metadata_path)
                        main_total_generate_dataset_size += getsize(metadata_path)

        # 4. Prepare and add manifest files to a list
        list_upload_manifest_files = []
        if "manifest-files" in soda_json_structure.keys():

            # prepare manifest files
            if soda_json_structure["starting-point"]["type"] == "bf":
                manifest_files_structure = (
                    create_high_level_manifest_files_existing_bf_starting_point(
                        soda_json_structure
                    )
                )
            else:
                if (
                    soda_json_structure["generate-dataset"]["destination"] == "bf"
                    and "dataset-name" not in soda_json_structure["generate-dataset"]
                ):
                    # generating dataset on an existing bf dataset - account for existing files and manifest files
                    manifest_files_structure = (
                        create_high_level_manifest_files_existing_bf(
                            soda_json_structure, bf, ds, tracking_json_structure
                        )
                    )
                else:
                    # generating on new bf
                    manifest_files_structure = create_high_level_manifest_files(
                        soda_json_structure
                    )

            # add manifest files to list after deleting existing ones
            list_upload_manifest_files = []
            for key in manifest_files_structure.keys():
                manifestpath = manifest_files_structure[key]
                item = tracking_json_structure["folders"][key]["value"]
                destination_folder_id = item.id
                # delete existing manifest files
                for subitem in item:
                    file_name_no_ext = os.path.splitext(subitem.name)[0]
                    if file_name_no_ext.lower() == "manifest":
                        subitem.delete()
                        item.update()
                # upload new manifest files
                list_upload_manifest_files.append([[manifestpath], item])
                main_total_generate_dataset_size += getsize(manifestpath)

        # clear the pennsieve queue
        clear_queue()
        
       #  print("Pennsieve queue cleared")
        print("\n")
        # print("List upload files all together: ", list_upload_files)
        print("\n")

        # 5. Upload files, rename, and add to tracking list
        main_initial_bfdataset_size = bf_dataset_size()
        start_generate = 1
        for item in list_upload_files:
            list_upload = item[0]
            # print("list upload item: ", list_upload)
            print("\n")
            bf_folder = item[1]
            list_projected_names = item[2]
            #print("The list of projected names is: ", list_projected_names)
            print("\n")
            list_desired_names = item[3]
            #print("The list of desired names is: ", list_desired_names)
            print("\n")
            list_final_names = item[4]
            #print("The list of final names is: ", list_final_names)
            print("\n")
            tracking_folder = item[5]
            relative_path = item[6]
            
            ## check if agent is running in the background
            # agent_running()
            
            # determine if the current folder's files exceeds 750 (past 750 is a breaking point atm)
            # if so proceed to batch uploading 
            if len(list_upload) > 750:
                print("Did execute bucketing")
                # store the aggregate of the amount of files in the folder
                total_files = len(list_upload)
                
                # create a start index and an end index
                start_index = end_index =  0
                
                # while startIndex < files.length 
                while start_index < total_files:
                    # set the endIndex to startIndex plus 750
                    end_index = start_index + 749
                    
                    # check if the endIndex is out of bounds
                    if end_index >= total_files: 
                        # if so set end index to files.length - 1
                        end_index = len(list_upload) - 1
                        
                    # get the 750 files between startIndex and endIndex (inclusive of endIndex)
                    upload_bucket = list_upload[start_index: end_index + 1]
                    
                    # inform the user files are being uploaded
                    main_curate_progress_message = "Uploading files in " + str(relative_path)
                    
                    # clear the pennsieve queue for successive batches
                    clear_queue()
                    
                    # upload the files
                    # bf_folder.upload(*upload_bucket)
           
                    # update the files 
                    # bf_folder.update()
                
                    print("Uploading a batch of files from ", start_index, "to ", end_index)
                    print("The upload files are: ", upload_bucket)
                
                    # handle renaming to final names
                    for index, projected_name in enumerate(list_projected_names[start_index:end_index + 1]):
                        final_name = list_final_names[index]
                        desired_name = list_desired_names[index]
                        if final_name != projected_name:
                            bf_item_list = bf_folder.items
                            (
                                my_bf_existing_files,
                                my_bf_existing_files_name,
                                my_bf_existing_files_name_with_extension,
                            ) = bf_get_existing_files_details(bf_folder)
                            for item in my_bf_existing_files:
                                if item.name == projected_name:
                                    item.name = final_name
                                    item.update()
                                    if "files" not in tracking_folder:
                                        tracking_folder["files"] = {}
                                        tracking_folder["files"][desired_name] = {"value": item}
                 
                    # update the start_index to end_index + 1
                    start_index = end_index + 1      
            else:
                # upload all files at once for the folder 
                main_curate_progress_message = "Uploading files in " + str(relative_path)
                print(main_curate_progress_message)
                print("\n")

                # fails when a single folder has more than 750 files (at which point I'm not sure)
                # bf_folder.upload(*list_upload)
                # bf_folder.update()
                print("Everything at once for the given folder:  ", list_upload)

                # rename to final name
                for index, projected_name in enumerate(list_projected_names):
                    final_name = list_final_names[index]
                    desired_name = list_desired_names[index]
                    if final_name != projected_name:
                        bf_item_list = bf_folder.items
                        (
                            my_bf_existing_files,
                            my_bf_existing_files_name,
                            my_bf_existing_files_name_with_extension,
                        ) = bf_get_existing_files_details(bf_folder)
                        for item in my_bf_existing_files:
                            if item.name == projected_name:
                                item.name = final_name
                                item.update()
                                if "files" not in tracking_folder:
                                    tracking_folder["files"] = {}
                                    tracking_folder["files"][desired_name] = {"value": item}

        if list_upload_metadata_files:
            main_curate_progress_message = (
                "Uploading metadata files in high-level dataset folder " + str(ds.name)
            )
            # ds.upload(*list_upload_metadata_files)

        if list_upload_manifest_files:
            for item in list_upload_manifest_files:
                manifest_file = item[0]
                bf_folder = item[1]
                main_curate_progress_message = (
                    "Uploading manifest file in " + str(bf_folder.name) + " folder"
                )
                # bf_folder.upload(*manifest_file)
                # bf_folder.update()
        shutil.rmtree(manifest_folder_path) if isdir(manifest_folder_path) else 0

    except Exception as e:
        raise e

# %%
# run the dataset updater function with the given soda json object 
main_curate_function(sodaJSONObject)
# Out:
# {'destination': 'bf', 'generate-option': 'existing-bf'}
# {'destination': 'bf', 'generate-option': 'existing-bf'}
# existing-bf
#
#
#
#
#
#
#
#
#
#
#
#
# Did execute bucketing
# Uploading a batch of files from  0 to  749
# ...
